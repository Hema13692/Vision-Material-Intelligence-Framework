# %%
from google.colab import drive
import zipfile
import os

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths
zip_path = "/content/drive/My Drive/archive 15000+15000=30000.zip"  # Change this
extract_path = "/content/unzipped_folder"  # Destination folder in Colab

# Create extraction directory
os.makedirs(extract_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
print("Unzipping done! Extracted files:")
for root, dirs, files in os.walk(extract_path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/unzipped_folder/Positive/13121.jpg
# /content/unzipped_folder/Positive/00538.jpg
# /content/unzipped_folder/Positive/02054.jpg
# /content/unzipped_folder/Positive/07901.jpg
# /content/unzipped_folder/Positive/13018.jpg
# /content/unzipped_folder/Positive/08280.jpg
# /content/unzipped_folder/Positive/10362.jpg
# /content/unzipped_folder/Positive/03864.jpg
# /content/unzipped_folder/Positive/14829.jpg
# /content/unzipped_folder/Positive/09220.jpg
# /content/unzipped_folder/Positive/11523.jpg
# /content/unzipped_folder/Positive/06664.jpg
# /content/unzipped_folder/Positive/11851.jpg
# /content/unzipped_folder/Positive/02000.jpg
# /content/unzipped_folder/Positive/11266.jpg
# /content/unzipped_folder/Positive/06161.jpg
# /content/unzipped_folder/Positive/11815.jpg
# /content/unzipped_folder/Positive/01849.jpg
# /content/unzipped_folder/Positive/11732.jpg
# /content/unzipped_folder/Positive/00797.jpg
# /content/unzipped_folder/Positive/03957.jpg
# /content/unzipped_folder/Positive/13335.jpg
# /content/unzipped_folder/Positive/14549.jpg
# /content/unzipped_folder/Positive/06920.jpg
# /content/unzipped_folder/Positive/07266.jpg
# /content/unzipped_folder/Positive/03337.jpg
# /content/unzipped_folder/Positive/00321.jpg
# /content/unzipped_folder/Positive/10482.jpg
# /content/unzipped_folder/Positive/01122.jpg
# /content/unzipped_folder/Positive/06330.jpg
# /content/unzipped_folder/Positive/03595.jpg
# /content/unzipped_folder/Positive/10061.jpg
# /content/unzipped_folder/Positive/00596.jpg
# /content/unzipped_folder/Positive/09633.jpg
# /content/unzipped_folder/Positive/12002.jpg
# /content/unzipped_folder/Positive/06501.jpg
# /content/unzipped_folder/Positive/12148.jpg
# /content/unzipped_folder/Positive/10419.jpg
# /content/unzipped_folder/Positive/11250.jpg
# /content/unzipped_folder/Positive/08141.jpg
# /content/unzipped_folder/Positive/04989.jpg
# /content/unzipped_folder/Positive/14055.jpg
# /content/unzipped_folder/Positive/08692.jpg
# /content/unzipped_folder/Positive/11501.jpg
# /content/unzipped_folder/Positive/04792.jpg
# /content/unzipped_folder/Positive/01784.jpg
# /content/unzipped_folder/Positive/03534.jpg
# /content/unzipped_folder/Positive/03048.jpg
# /content/unzipped_folder/Positive/06533.jpg
# /content/unzipped_folder/Positive/10994.jpg
# /content/unzipped_folder/Positive/09579.jpg
# /content/unzipped_folder/Positive/04090.jpg
# /content/unzipped_folder/Positive/00159.jpg
# /content/unzipped_folder/Positive/01346.jpg
# /content/unzipped_folder/Positive/13756.jpg
# /content/unzipped_folder/Positive/06175.jpg
# /content/unzipped_folder/Positive/11647.jpg
# /content/unzipped_folder/Positive/14617.jpg
# /content/unzipped_folder/Positive/02627.jpg
# /content/unzipped_folder/Positive/11057.jpg
# /content/unzipped_folder/Positive/04383.jpg
# /content/unzipped_folder/Positive/11185.jpg
# /content/unzipped_folder/Positive/05022.jpg
# /content/unzipped_folder/Positive/11158.jpg
# /content/unzipped_folder/Positive/13561.jpg
# /content/unzipped_folder/Positive/01962.jpg
# /content/unzipped_folder/Positive/07290.jpg
# /content/unzipped_folder/Positive/12514.jpg
# /content/unzipped_folder/Positive/00285.jpg
# /content/unzipped_folder/Positive/04552.jpg
# /content/unzipped_folder/Positive/02640.jpg
# /content/unzipped_folder/Positive/04299.jpg
# /content/unzipped_folder/Positive/01220.jpg
# /content/unzipped_folder/Positive/05808.jpg
# /content/unzipped_folder/Positive/10259.jpg
# /content/unzipped_folder/Positive/09903.jpg
# /content/unzipped_folder/Positive/06749.jpg
# /content/unzipped_folder/Positive/12318.jpg
# /content/unzipped_folder/Positive/11858.jpg
# /content/unzipped_folder/Positive/09046.jpg
# /content/unzipped_folder/Positive/01434.jpg
# /content/unzipped_folder/Positive/08299.jpg
# /content/unzipped_folder/Positive/11109.jpg
# /content/unzipped_folder/Positive/09476.jpg
# /content/unzipped_folder/Positive/09824.jpg
# /content/unzipped_folder/Positive/13887.jpg
# /content/unzipped_folder/Positive/05374.jpg
# /content/unzipped_folder/Positive/02827.jpg
# /content/unzipped_folder/Positive/01085.jpg
# /content/unzipped_folder/Positive/04764.jpg
# /content/unzipped_folder/Positive/09851.jpg
# /content/unzipped_folder/Positive/03791.jpg
# /content/unzipped_folder/Positive/12193.jpg
# /content/unzipped_folder/Positive/11765.jpg
# /content/unzipped_folder/Positive/05714.jpg
# /content/unzipped_folder/Positive/11681.jpg
# /content/unzipped_folder/Positive/06207.jpg
# /content/unzipped_folder/Positive/11808.jpg
# /content/unzipped_folder/Positive/09172.jpg
# /content/unzipped_folder/Positive/12037.jpg
# /content/unzipped_folder/Positive/06646.jpg
# /content/unzipped_folder/Positive/12053.jpg
# /content/unzipped_folder/Positive/08309.jpg
# /content/unzipped_folder/Positive/01418.jpg
# /content/unzipped_folder/Positive/05801.jpg
# /content/unzipped_folder/Positive/01203.jpg
# /content/unzipped_folder/Positive/05748.jpg
# /content/unzipped_folder/Positive/01396.jpg
# /content/unzipped_folder/Positive/12697.jpg
# /content/unzipped_folder/Positive/14889.jpg
# /content/unzipped_folder/Positive/14010.jpg
# /content/unzipped_folder/Positive/12119.jpg
# /content/unzipped_folder/Positive/08551.jpg
# /content/unzipped_folder/Positive/11429.jpg
# /content/unzipped_folder/Positive/10998.jpg
# /content/unzipped_folder/Positive/14837.jpg
# /content/unzipped_folder/Positive/13604.jpg
# /content/unzipped_folder/Positive/07976.jpg
# /content/unzipped_folder/Positive/01171.jpg
# /content/unzipped_folder/Positive/03067.jpg
# /content/unzipped_folder/Positive/08180.jpg
# /content/unzipped_folder/Positive/11000.jpg
# /content/unzipped_folder/Positive/13911.jpg
# /content/unzipped_folder/Positive/01035.jpg
# /content/unzipped_folder/Positive/14936.jpg
# /content/unzipped_folder/Positive/14646.jpg
# /content/unzipped_folder/Positive/11152.jpg
# /content/unzipped_folder/Positive/09426.jpg
# /content/unzipped_folder/Positive/13197.jpg
# /content/unzipped_folder/Positive/01557.jpg
# /content/unzipped_folder/Positive/14738.jpg
# /content/unzipped_folder/Positive/05926.jpg
# /content/unzipped_folder/Positive/04587.jpg
# /content/unzipped_folder/Positive/05343.jpg
# /content/unzipped_folder/Positive/10642.jpg
# /content/unzipped_folder/Positive/07740.jpg
# /content/unzipped_folder/Positive/12181.jpg
# /content/unzipped_folder/Positive/07800.jpg
# /content/unzipped_folder/Positive/04688.jpg
# /content/unzipped_folder/Positive/01790.jpg
# /content/unzipped_folder/Positive/08497.jpg
# /content/unzipped_folder/Positive/05803.jpg
# /content/unzipped_folder/Positive/03242.jpg
# /content/unzipped_folder/Positive/10070.jpg
# /content/unzipped_folder/Positive/14364.jpg
# /content/unzipped_folder/Positive/06276.jpg
# /content/unzipped_folder/Positive/07021.jpg
# /content/unzipped_folder/Positive/05544.jpg
# /content/unzipped_folder/Positive/09116.jpg
# /content/unzipped_folder/Positive/09556.jpg
# /content/unzipped_folder/Positive/03822.jpg
# /content/unzipped_folder/Positive/06389.jpg
# /content/unzipped_folder/Positive/05934.jpg
# /content/unzipped_folder/Positive/02002.jpg
# /content/unzipped_folder/Positive/01028.jpg
# /content/unzipped_folder/Positive/14514.jpg
# /content/unzipped_folder/Positive/04583.jpg
# /content/unzipped_folder/Positive/08855.jpg
# /content/unzipped_folder/Positive/05321.jpg
# /content/unzipped_folder/Positive/00982.jpg
# /content/unzipped_folder/Positive/11660.jpg
# /content/unzipped_folder/Positive/05018.jpg
# /content/unzipped_folder/Positive/14074.jpg
# /content/unzipped_folder/Positive/11889.jpg
# /content/unzipped_folder/Positive/09868.jpg
# /content/unzipped_folder/Positive/01732.jpg
# /content/unzipped_folder/Positive/04516.jpg
# /content/unzipped_folder/Positive/09886.jpg
# /content/unzipped_folder/Positive/03386.jpg
# /content/unzipped_folder/Positive/06915.jpg
# /content/unzipped_folder/Positive/10544.jpg
# /content/unzipped_folder/Positive/07956.jpg
# /content/unzipped_folder/Positive/05581.jpg
# /content/unzipped_folder/Positive/00365.jpg
# /content/unzipped_folder/Positive/14086.jpg
# /content/unzipped_folder/Positive/12680.jpg
# /content/unzipped_folder/Positive/07689.jpg
# /content/unzipped_folder/Positive/11493.jpg
# /content/unzipped_folder/Positive/06948.jpg
# /content/unzipped_folder/Positive/13910.jpg
# /content/unzipped_folder/Positive/13932.jpg
# /content/unzipped_folder/Positive/01135.jpg
# /content/unzipped_folder/Positive/02442.jpg
# /content/unzipped_folder/Positive/09540.jpg
# /content/unzipped_folder/Positive/08752.jpg
# /content/unzipped_folder/Positive/09736.jpg
# /content/unzipped_folder/Positive/08693.jpg
# /content/unzipped_folder/Positive/13341.jpg
# /content/unzipped_folder/Positive/14069.jpg
# /content/unzipped_folder/Positive/03204.jpg
# /content/unzipped_folder/Positive/05404.jpg
# /content/unzipped_folder/Positive/11491.jpg
# /content/unzipped_folder/Positive/03967.jpg
# /content/unzipped_folder/Positive/00594.jpg
# /content/unzipped_folder/Positive/08890.jpg
# /content/unzipped_folder/Positive/07116.jpg
# /content/unzipped_folder/Positive/09737.jpg
# /content/unzipped_folder/Positive/06034.jpg
# /content/unzipped_folder/Positive/02898.jpg
# /content/unzipped_folder/Positive/10520.jpg
# /content/unzipped_folder/Positive/09637.jpg
# /content/unzipped_folder/Positive/00417.jpg
# /content/unzipped_folder/Positive/05990.jpg
# /content/unzipped_folder/Positive/02653.jpg
# /content/unzipped_folder/Positive/00575.jpg
# /content/unzipped_folder/Positive/14665.jpg
# /content/unzipped_folder/Positive/14377.jpg
# /content/unzipped_folder/Positive/11450.jpg
# /content/unzipped_folder/Positive/01864.jpg
# /content/unzipped_folder/Positive/07219.jpg
# /content/unzipped_folder/Positive/03786.jpg
# /content/unzipped_folder/Positive/10935.jpg
# /content/unzipped_folder/Positive/01939.jpg
# /content/unzipped_folder/Positive/12132.jpg
# /content/unzipped_folder/Positive/01355.jpg
# /content/unzipped_folder/Positive/01867.jpg
# /content/unzipped_folder/Positive/13384.jpg
# /content/unzipped_folder/Positive/04734.jpg
# /content/unzipped_folder/Positive/00132.jpg
# /content/unzipped_folder/Positive/05570.jpg
# /content/unzipped_folder/Positive/10080.jpg
# /content/unzipped_folder/Positive/09144.jpg
# /content/unzipped_folder/Positive/10576.jpg
# /content/unzipped_folder/Positive/05702.jpg
# /content/unzipped_folder/Positive/10725.jpg
# /content/unzipped_folder/Positive/12313.jpg
# /content/unzipped_folder/Positive/04242.jpg
# /content/unzipped_folder/Positive/04780.jpg
# /content/unzipped_folder/Positive/04739.jpg
# /content/unzipped_folder/Positive/11258.jpg
# /content/unzipped_folder/Positive/06705.jpg
# /content/unzipped_folder/Positive/02119.jpg
# /content/unzipped_folder/Positive/11434.jpg
# /content/unzipped_folder/Positive/00326.jpg
# /content/unzipped_folder/Positive/14328.jpg
# /content/unzipped_folder/Positive/04105.jpg
# /content/unzipped_folder/Positive/00272.jpg
# /content/unzipped_folder/Positive/00910.jpg
# /content/unzipped_folder/Positive/09747.jpg
# /content/unzipped_folder/Positive/12403.jpg
# /content/unzipped_folder/Positive/09274.jpg
# /content/unzipped_folder/Positive/12646.jpg
# /content/unzipped_folder/Positive/14160.jpg
# /content/unzipped_folder/Positive/01871.jpg
# /content/unzipped_folder/Positive/05152.jpg
# /content/unzipped_folder/Positive/01797.jpg
# /content/unzipped_folder/Positive/11454.jpg
# /content/unzipped_folder/Positive/02711.jpg
# /content/unzipped_folder/Positive/08349.jpg
# /content/unzipped_folder/Positive/06210.jpg
# /content/unzipped_folder/Positive/01516.jpg
# /content/unzipped_folder/Positive/13460.jpg
# /content/unzipped_folder/Positive/01915.jpg
# /content/unzipped_folder/Positive/02868.jpg
# /content/unzipped_folder/Positive/10832.jpg
# /content/unzipped_folder/Positive/05445.jpg
# /content/unzipped_folder/Positive/12161.jpg
# /content/unzipped_folder/Positive/00244.jpg
# /content/unzipped_folder/Positive/02466.jpg
# /content/unzipped_folder/Positive/11698.jpg
# /content/unzipped_folder/Positive/13880.jpg
# /content/unzipped_folder/Positive/09430.jpg
# /content/unzipped_folder/Positive/10350.jpg
# /content/unzipped_folder/Positive/05735.jpg
# /content/unzipped_folder/Positive/12874.jpg
# /content/unzipped_folder/Positive/05171.jpg
# /content/unzipped_folder/Positive/07622.jpg
# /content/unzipped_folder/Positive/02326.jpg
# /content/unzipped_folder/Positive/03282.jpg
# /content/unzipped_folder/Positive/05940.jpg
# /content/unzipped_folder/Positive/14909.jpg
# /content/unzipped_folder/Positive/00095.jpg
# /content/unzipped_folder/Positive/06719.jpg
# /content/unzipped_folder/Positive/10484.jpg
# /content/unzipped_folder/Positive/12377.jpg
# /content/unzipped_folder/Positive/03747.jpg
# /content/unzipped_folder/Positive/07211.jpg
# /content/unzipped_folder/Positive/11426.jpg
# /content/unzipped_folder/Positive/01739.jpg
# /content/unzipped_folder/Positive/07890.jpg
# /content/unzipped_folder/Positive/04846.jpg
# /content/unzipped_folder/Positive/10909.jpg
# /content/unzipped_folder/Positive/04613.jpg
# /content/unzipped_folder/Positive/02776.jpg
# /content/unzipped_folder/Positive/14631.jpg
# /content/unzipped_folder/Positive/05424.jpg
# /content/unzipped_folder/Positive/02395.jpg
# /content/unzipped_folder/Positive/09444.jpg
# /content/unzipped_folder/Positive/02384.jpg
# /content/unzipped_folder/Positive/03974.jpg
# /content/unzipped_folder/Positive/07285.jpg
# /content/unzipped_folder/Positive/08731.jpg
# /content/unzipped_folder/Positive/00938.jpg
# /content/unzipped_folder/Positive/02396.jpg
# /content/unzipped_folder/Positive/05840.jpg
# /content/unzipped_folder/Positive/14180.jpg
# /content/unzipped_folder/Positive/02814.jpg
# /content/unzipped_folder/Positive/02285.jpg
# /content/unzipped_folder/Positive/03045.jpg
# /content/unzipped_folder/Positive/11213.jpg
# /content/unzipped_folder/Positive/00563.jpg
# /content/unzipped_folder/Positive/00434.jpg
# /content/unzipped_folder/Positive/01328.jpg
# /content/unzipped_folder/Positive/11088.jpg
# /content/unzipped_folder/Positive/11207.jpg
# /content/unzipped_folder/Positive/02587.jpg
# /content/unzipped_folder/Positive/06525.jpg
# /content/unzipped_folder/Positive/03587.jpg
# /content/unzipped_folder/Positive/01024.jpg
# /content/unzipped_folder/Positive/14382.jpg
# /content/unzipped_folder/Positive/04612.jpg
# /content/unzipped_folder/Positive/11728.jpg
# /content/unzipped_folder/Positive/09401.jpg
# /content/unzipped_folder/Positive/01690.jpg
# /content/unzipped_folder/Positive/10644.jpg
# /content/unzipped_folder/Positive/07056.jpg
# /content/unzipped_folder/Positive/07011.jpg
# /content/unzipped_folder/Positive/07423.jpg
# /content/unzipped_folder/Positive/11189.jpg
# /content/unzipped_folder/Positive/11565.jpg
# /content/unzipped_folder/Positive/08256.jpg
# /content/unzipped_folder/Positive/05558.jpg
# /content/unzipped_folder/Positive/04186.jpg
# /content/unzipped_folder/Positive/04887.jpg
# /content/unzipped_folder/Positive/07398.jpg
# /content/unzipped_folder/Positive/02683.jpg
# /content/unzipped_folder/Positive/04476.jpg
# /content/unzipped_folder/Positive/04690.jpg
# /content/unzipped_folder/Positive/06232.jpg
# /content/unzipped_folder/Positive/03975.jpg
# /content/unzipped_folder/Positive/08060.jpg
# /content/unzipped_folder/Positive/13991.jpg
# /content/unzipped_folder/Positive/00942.jpg
# /content/unzipped_folder/Positive/12882.jpg
# /content/unzipped_folder/Positive/00697.jpg
# /content/unzipped_folder/Positive/02579.jpg
# /content/unzipped_folder/Positive/13755.jpg
# /content/unzipped_folder/Positive/01931.jpg
# /content/unzipped_folder/Positive/00752.jpg
# /content/unzipped_folder/Positive/07327.jpg
# /content/unzipped_folder/Positive/07172.jpg
# /content/unzipped_folder/Positive/07010.jpg
# /content/unzipped_folder/Positive/12136.jpg
# /content/unzipped_folder/Positive/01735.jpg
# /content/unzipped_folder/Positive/10938.jpg
# /content/unzipped_folder/Positive/09293.jpg
# /content/unzipped_folder/Positive/04847.jpg
# /content/unzipped_folder/Positive/07256.jpg
# /content/unzipped_folder/Positive/12082.jpg
# /content/unzipped_folder/Positive/03790.jpg
# /content/unzipped_folder/Positive/08595.jpg
# /content/unzipped_folder/Positive/03556.jpg
# /content/unzipped_folder/Positive/01565.jpg
# /content/unzipped_folder/Positive/10095.jpg
# /content/unzipped_folder/Positive/14976.jpg
# /content/unzipped_folder/Positive/08840.jpg
# /content/unzipped_folder/Positive/04712.jpg
# /content/unzipped_folder/Positive/14805.jpg
# /content/unzipped_folder/Positive/03131.jpg
# /content/unzipped_folder/Positive/07830.jpg
# /content/unzipped_folder/Positive/12533.jpg
# /content/unzipped_folder/Positive/00958.jpg
# /content/unzipped_folder/Positive/10578.jpg
# /content/unzipped_folder/Positive/09093.jpg
# /content/unzipped_folder/Positive/08440.jpg
# /content/unzipped_folder/Positive/03633.jpg
# /content/unzipped_folder/Positive/00004.jpg
# /content/unzipped_folder/Positive/03845.jpg
# /content/unzipped_folder/Positive/06823.jpg
# /content/unzipped_folder/Positive/02538.jpg
# /content/unzipped_folder/Positive/05788.jpg
# /content/unzipped_folder/Positive/12023.jpg
# /content/unzipped_folder/Positive/07730.jpg
# /content/unzipped_folder/Positive/03925.jpg
# /content/unzipped_folder/Positive/07030.jpg
# /content/unzipped_folder/Positive/11956.jpg
# /content/unzipped_folder/Positive/01014.jpg
# /content/unzipped_folder/Positive/08878.jpg
# /content/unzipped_folder/Positive/04321.jpg
# /content/unzipped_folder/Positive/04320.jpg
# /content/unzipped_folder/Positive/08521.jpg
# /content/unzipped_folder/Positive/06497.jpg
# /content/unzipped_folder/Positive/11197.jpg
# /content/unzipped_folder/Positive/06825.jpg
# /content/unzipped_folder/Positive/02668.jpg
# /content/unzipped_folder/Positive/05663.jpg
# /content/unzipped_folder/Positive/03668.jpg
# /content/unzipped_folder/Positive/02151.jpg
# /content/unzipped_folder/Positive/09477.jpg
# /content/unzipped_folder/Positive/12936.jpg
# /content/unzipped_folder/Positive/01771.jpg
# /content/unzipped_folder/Positive/03675.jpg
# /content/unzipped_folder/Positive/12524.jpg
# /content/unzipped_folder/Positive/10973.jpg
# /content/unzipped_folder/Positive/02441.jpg
# /content/unzipped_folder/Positive/13934.jpg
# /content/unzipped_folder/Positive/09259.jpg
# /content/unzipped_folder/Positive/06241.jpg
# /content/unzipped_folder/Positive/04867.jpg
# /content/unzipped_folder/Positive/10422.jpg
# /content/unzipped_folder/Positive/01779.jpg
# /content/unzipped_folder/Positive/04548.jpg
# /content/unzipped_folder/Positive/06117.jpg
# /content/unzipped_folder/Positive/03103.jpg
# /content/unzipped_folder/Positive/06331.jpg
# /content/unzipped_folder/Positive/05994.jpg
# /content/unzipped_folder/Positive/11124.jpg
# /content/unzipped_folder/Positive/00393.jpg
# /content/unzipped_folder/Positive/13397.jpg
# /content/unzipped_folder/Positive/11658.jpg
# /content/unzipped_folder/Positive/12968.jpg
# /content/unzipped_folder/Positive/07907.jpg
# /content/unzipped_folder/Positive/11980.jpg
# /content/unzipped_folder/Positive/05741.jpg
# /content/unzipped_folder/Positive/10340.jpg
# /content/unzipped_folder/Positive/10810.jpg
# /content/unzipped_folder/Positive/03520.jpg
# /content/unzipped_folder/Positive/06601.jpg
# /content/unzipped_folder/Positive/08716.jpg
# /content/unzipped_folder/Positive/14845.jpg
# /content/unzipped_folder/Positive/11653.jpg
# /content/unzipped_folder/Positive/09586.jpg
# /content/unzipped_folder/Positive/06068.jpg
# /content/unzipped_folder/Positive/14790.jpg
# /content/unzipped_folder/Positive/02168.jpg
# /content/unzipped_folder/Positive/13822.jpg
# /content/unzipped_folder/Positive/09230.jpg
# /content/unzipped_folder/Positive/07121.jpg
# /content/unzipped_folder/Positive/06568.jpg
# /content/unzipped_folder/Positive/09365.jpg
# /content/unzipped_folder/Positive/10472.jpg
# /content/unzipped_folder/Positive/08606.jpg
# /content/unzipped_folder/Positive/12123.jpg
# /content/unzipped_folder/Positive/14652.jpg
# /content/unzipped_folder/Positive/00874.jpg
# /content/unzipped_folder/Positive/03560.jpg
# /content/unzipped_folder/Positive/11661.jpg
# /content/unzipped_folder/Positive/06400.jpg
# /content/unzipped_folder/Positive/13041.jpg
# /content/unzipped_folder/Positive/13491.jpg
# /content/unzipped_folder/Positive/08912.jpg
# /content/unzipped_folder/Positive/00403.jpg
# /content/unzipped_folder/Positive/12456.jpg
# /content/unzipped_folder/Positive/03295.jpg
# /content/unzipped_folder/Positive/13030.jpg
# /content/unzipped_folder/Positive/10137.jpg
# /content/unzipped_folder/Positive/00576.jpg
# /content/unzipped_folder/Positive/01539.jpg
# /content/unzipped_folder/Positive/13270.jpg
# /content/unzipped_folder/Positive/09178.jpg
# /content/unzipped_folder/Positive/03771.jpg
# /content/unzipped_folder/Positive/13592.jpg
# /content/unzipped_folder/Positive/07323.jpg
# /content/unzipped_folder/Positive/12440.jpg
# /content/unzipped_folder/Positive/03784.jpg
# /content/unzipped_folder/Positive/00423.jpg
# /content/unzipped_folder/Positive/13437.jpg
# /content/unzipped_folder/Positive/11532.jpg
# /content/unzipped_folder/Positive/06121.jpg
# /content/unzipped_folder/Positive/04793.jpg
# /content/unzipped_folder/Positive/09644.jpg
# /content/unzipped_folder/Positive/05323.jpg
# /content/unzipped_folder/Positive/00381.jpg
# /content/unzipped_folder/Positive/12871.jpg
# /content/unzipped_folder/Positive/14295.jpg
# /content/unzipped_folder/Positive/14785.jpg
# /content/unzipped_folder/Positive/04962.jpg
# /content/unzipped_folder/Positive/12537.jpg
# /content/unzipped_folder/Positive/01547.jpg
# /content/unzipped_folder/Positive/13600.jpg
# /content/unzipped_folder/Positive/03592.jpg
# /content/unzipped_folder/Positive/05531.jpg
# /content/unzipped_folder/Positive/01926.jpg
# /content/unzipped_folder/Positive/00451.jpg
# /content/unzipped_folder/Positive/05930.jpg
# /content/unzipped_folder/Positive/10364.jpg
# /content/unzipped_folder/Positive/00161.jpg
# /content/unzipped_folder/Positive/13921.jpg
# /content/unzipped_folder/Positive/13593.jpg
# /content/unzipped_folder/Positive/04411.jpg
# /content/unzipped_folder/Positive/02497.jpg
# /content/unzipped_folder/Positive/08807.jpg
# /content/unzipped_folder/Positive/06321.jpg
# /content/unzipped_folder/Positive/04974.jpg
# /content/unzipped_folder/Positive/06555.jpg
# /content/unzipped_folder/Positive/06926.jpg
# /content/unzipped_folder/Positive/01563.jpg
# /content/unzipped_folder/Positive/09434.jpg
# /content/unzipped_folder/Positive/04668.jpg
# /content/unzipped_folder/Positive/02351.jpg
# /content/unzipped_folder/Positive/01681.jpg
# /content/unzipped_folder/Positive/10933.jpg
# /content/unzipped_folder/Positive/01000.jpg
# /content/unzipped_folder/Positive/09614.jpg
# /content/unzipped_folder/Positive/08270.jpg
# /content/unzipped_folder/Positive/12211.jpg
# /content/unzipped_folder/Positive/05609.jpg
# /content/unzipped_folder/Positive/09789.jpg
# /content/unzipped_folder/Positive/14713.jpg
# /content/unzipped_folder/Positive/13843.jpg
# /content/unzipped_folder/Positive/14476.jpg
# /content/unzipped_folder/Positive/09896.jpg
# /content/unzipped_folder/Positive/14293.jpg
# /content/unzipped_folder/Positive/11846.jpg
# /content/unzipped_folder/Positive/02234.jpg
# /content/unzipped_folder/Positive/12835.jpg
# /content/unzipped_folder/Positive/07552.jpg
# /content/unzipped_folder/Positive/06240.jpg
# /content/unzipped_folder/Positive/06129.jpg
# /content/unzipped_folder/Positive/13621.jpg
# /content/unzipped_folder/Positive/10708.jpg
# /content/unzipped_folder/Positive/05648.jpg
# /content/unzipped_folder/Positive/00315.jpg
# /content/unzipped_folder/Positive/00449.jpg
# /content/unzipped_folder/Positive/14970.jpg
# /content/unzipped_folder/Positive/05223.jpg
# /content/unzipped_folder/Positive/13184.jpg
# /content/unzipped_folder/Positive/08045.jpg
# /content/unzipped_folder/Positive/07874.jpg
# /content/unzipped_folder/Positive/00399.jpg
# /content/unzipped_folder/Positive/07960.jpg
# /content/unzipped_folder/Positive/05100.jpg
# /content/unzipped_folder/Positive/04053.jpg
# /content/unzipped_folder/Positive/04491.jpg
# /content/unzipped_folder/Positive/01624.jpg
# /content/unzipped_folder/Positive/06114.jpg
# /content/unzipped_folder/Positive/04719.jpg
# /content/unzipped_folder/Positive/04025.jpg
# /content/unzipped_folder/Positive/13594.jpg
# /content/unzipped_folder/Positive/13374.jpg
# /content/unzipped_folder/Positive/09329.jpg
# /content/unzipped_folder/Positive/07147.jpg
# /content/unzipped_folder/Positive/12619.jpg
# /content/unzipped_folder/Positive/14994.jpg
# /content/unzipped_folder/Positive/05718.jpg
# /content/unzipped_folder/Positive/03973.jpg
# /content/unzipped_folder/Positive/13386.jpg
# /content/unzipped_folder/Positive/14874.jpg
# /content/unzipped_folder/Positive/01916.jpg
# /content/unzipped_folder/Positive/05010.jpg
# /content/unzipped_folder/Positive/03419.jpg
# /content/unzipped_folder/Positive/06396.jpg
# /content/unzipped_folder/Positive/04748.jpg
# /content/unzipped_folder/Positive/05224.jpg
# /content/unzipped_folder/Positive/12157.jpg
# /content/unzipped_folder/Positive/00408.jpg
# /content/unzipped_folder/Positive/01134.jpg
# /content/unzipped_folder/Positive/07920.jpg
# /content/unzipped_folder/Positive/10552.jpg
# /content/unzipped_folder/Positive/13084.jpg
# /content/unzipped_folder/Positive/11772.jpg
# /content/unzipped_folder/Positive/00768.jpg
# /content/unzipped_folder/Positive/09785.jpg
# /content/unzipped_folder/Positive/14256.jpg
# /content/unzipped_folder/Positive/13979.jpg
# /content/unzipped_folder/Positive/13355.jpg
# /content/unzipped_folder/Positive/11934.jpg
# /content/unzipped_folder/Positive/11946.jpg
# /content/unzipped_folder/Positive/00198.jpg
# /content/unzipped_folder/Positive/01613.jpg
# /content/unzipped_folder/Positive/08154.jpg
# /content/unzipped_folder/Positive/05654.jpg
# /content/unzipped_folder/Positive/12953.jpg
# /content/unzipped_folder/Positive/00716.jpg
# /content/unzipped_folder/Positive/13535.jpg
# /content/unzipped_folder/Positive/07191.jpg
# /content/unzipped_folder/Positive/04176.jpg
# /content/unzipped_folder/Positive/04538.jpg
# /content/unzipped_folder/Positive/13326.jpg
# /content/unzipped_folder/Positive/04083.jpg
# /content/unzipped_folder/Positive/07016.jpg
# /content/unzipped_folder/Positive/06302.jpg
# /content/unzipped_folder/Positive/10352.jpg
# /content/unzipped_folder/Positive/07162.jpg
# /content/unzipped_folder/Positive/14880.jpg
# /content/unzipped_folder/Positive/08871.jpg
# /content/unzipped_folder/Positive/06653.jpg
# /content/unzipped_folder/Positive/00578.jpg
# /content/unzipped_folder/Positive/00922.jpg
# /content/unzipped_folder/Positive/07054.jpg
# /content/unzipped_folder/Positive/10171.jpg
# /content/unzipped_folder/Positive/01200.jpg
# /content/unzipped_folder/Positive/08231.jpg
# /content/unzipped_folder/Positive/12146.jpg
# /content/unzipped_folder/Positive/03389.jpg
# /content/unzipped_folder/Positive/07953.jpg
# /content/unzipped_folder/Positive/03582.jpg
# /content/unzipped_folder/Positive/00458.jpg
# /content/unzipped_folder/Positive/07836.jpg
# /content/unzipped_folder/Positive/02529.jpg
# /content/unzipped_folder/Positive/01729.jpg
# /content/unzipped_folder/Positive/07497.jpg
# /content/unzipped_folder/Positive/10132.jpg
# /content/unzipped_folder/Positive/09527.jpg
# /content/unzipped_folder/Positive/14489.jpg
# /content/unzipped_folder/Positive/10201.jpg
# /content/unzipped_folder/Positive/02046.jpg
# /content/unzipped_folder/Positive/12503.jpg
# /content/unzipped_folder/Positive/12325.jpg
# /content/unzipped_folder/Positive/10964.jpg
# /content/unzipped_folder/Positive/01041.jpg
# /content/unzipped_folder/Positive/14111.jpg
# /content/unzipped_folder/Positive/06409.jpg
# /content/unzipped_folder/Positive/10140.jpg
# /content/unzipped_folder/Positive/01409.jpg
# /content/unzipped_folder/Positive/11784.jpg
# /content/unzipped_folder/Positive/13278.jpg
# /content/unzipped_folder/Positive/14064.jpg
# /content/unzipped_folder/Positive/06639.jpg
# /content/unzipped_folder/Positive/05845.jpg
# /content/unzipped_folder/Positive/14258.jpg
# /content/unzipped_folder/Positive/07925.jpg
# /content/unzipped_folder/Positive/14962.jpg
# /content/unzipped_folder/Positive/10735.jpg
# /content/unzipped_folder/Positive/01840.jpg
# /content/unzipped_folder/Positive/07428.jpg
# /content/unzipped_folder/Positive/08674.jpg
# /content/unzipped_folder/Positive/08913.jpg
# /content/unzipped_folder/Positive/10747.jpg
# /content/unzipped_folder/Positive/13488.jpg
# /content/unzipped_folder/Positive/12275.jpg
# /content/unzipped_folder/Positive/04956.jpg
# /content/unzipped_folder/Positive/02311.jpg
# /content/unzipped_folder/Positive/00571.jpg
# /content/unzipped_folder/Positive/04442.jpg
# /content/unzipped_folder/Positive/06373.jpg
# /content/unzipped_folder/Positive/02490.jpg
# /content/unzipped_folder/Positive/06953.jpg
# /content/unzipped_folder/Positive/04363.jpg
# /content/unzipped_folder/Positive/12698.jpg
# /content/unzipped_folder/Positive/08156.jpg
# /content/unzipped_folder/Positive/05677.jpg
# /content/unzipped_folder/Positive/10768.jpg
# /content/unzipped_folder/Positive/12289.jpg
# /content/unzipped_folder/Positive/10447.jpg
# /content/unzipped_folder/Positive/05135.jpg
# /content/unzipped_folder/Positive/08597.jpg
# /content/unzipped_folder/Positive/00115.jpg
# /content/unzipped_folder/Positive/03167.jpg
# /content/unzipped_folder/Positive/03139.jpg
# /content/unzipped_folder/Positive/09484.jpg
# /content/unzipped_folder/Positive/10876.jpg
# /content/unzipped_folder/Positive/05333.jpg
# /content/unzipped_folder/Positive/10543.jpg
# /content/unzipped_folder/Positive/11411.jpg
# /content/unzipped_folder/Positive/14266.jpg
# /content/unzipped_folder/Positive/12068.jpg
# /content/unzipped_folder/Positive/10408.jpg
# /content/unzipped_folder/Positive/02139.jpg
# /content/unzipped_folder/Positive/11672.jpg
# /content/unzipped_folder/Positive/10694.jpg
# /content/unzipped_folder/Positive/08129.jpg
# /content/unzipped_folder/Positive/03631.jpg
# /content/unzipped_folder/Positive/02808.jpg
# /content/unzipped_folder/Positive/11390.jpg
# /content/unzipped_folder/Positive/11436.jpg
# /content/unzipped_folder/Positive/02700.jpg
# /content/unzipped_folder/Positive/07305.jpg
# /content/unzipped_folder/Positive/05683.jpg
# /content/unzipped_folder/Positive/12406.jpg
# /content/unzipped_folder/Positive/04953.jpg
# /content/unzipped_folder/Positive/08625.jpg
# /content/unzipped_folder/Positive/12534.jpg
# /content/unzipped_folder/Positive/06225.jpg
# /content/unzipped_folder/Positive/04916.jpg
# /content/unzipped_folder/Positive/13815.jpg
# /content/unzipped_folder/Positive/09491.jpg
# /content/unzipped_folder/Positive/14649.jpg
# /content/unzipped_folder/Positive/08255.jpg
# /content/unzipped_folder/Positive/04018.jpg
# /content/unzipped_folder/Positive/08394.jpg
# /content/unzipped_folder/Positive/01472.jpg
# /content/unzipped_folder/Positive/02939.jpg
# /content/unzipped_folder/Positive/01519.jpg
# /content/unzipped_folder/Positive/12291.jpg
# /content/unzipped_folder/Positive/08939.jpg
# /content/unzipped_folder/Positive/11942.jpg
# /content/unzipped_folder/Positive/10516.jpg
# /content/unzipped_folder/Positive/03310.jpg
# /content/unzipped_folder/Positive/09762.jpg
# /content/unzipped_folder/Positive/12701.jpg
# /content/unzipped_folder/Positive/06975.jpg
# /content/unzipped_folder/Positive/08568.jpg
# /content/unzipped_folder/Positive/11418.jpg
# /content/unzipped_folder/Positive/06987.jpg
# /content/unzipped_folder/Positive/10903.jpg
# /content/unzipped_folder/Positive/05429.jpg
# /content/unzipped_folder/Positive/05501.jpg
# /content/unzipped_folder/Positive/05087.jpg
# /content/unzipped_folder/Positive/01698.jpg
# /content/unzipped_folder/Positive/05467.jpg
# /content/unzipped_folder/Positive/07342.jpg
# /content/unzipped_folder/Positive/03274.jpg
# /content/unzipped_folder/Positive/03961.jpg
# /content/unzipped_folder/Positive/12396.jpg
# /content/unzipped_folder/Positive/00031.jpg
# /content/unzipped_folder/Positive/12344.jpg
# /content/unzipped_folder/Positive/04779.jpg
# /content/unzipped_folder/Positive/05521.jpg
# /content/unzipped_folder/Positive/14839.jpg
# /content/unzipped_folder/Positive/08772.jpg
# /content/unzipped_folder/Positive/07122.jpg
# /content/unzipped_folder/Positive/14727.jpg
# /content/unzipped_folder/Positive/07135.jpg
# /content/unzipped_folder/Positive/06183.jpg
# /content/unzipped_folder/Positive/13065.jpg
# /content/unzipped_folder/Positive/04200.jpg
# /content/unzipped_folder/Positive/04937.jpg
# /content/unzipped_folder/Positive/08877.jpg
# /content/unzipped_folder/Positive/12550.jpg
# /content/unzipped_folder/Positive/00504.jpg
# /content/unzipped_folder/Positive/11619.jpg
# /content/unzipped_folder/Positive/00221.jpg
# /content/unzipped_folder/Positive/14260.jpg
# /content/unzipped_folder/Positive/05971.jpg
# /content/unzipped_folder/Positive/06097.jpg
# /content/unzipped_folder/Positive/13869.jpg
# /content/unzipped_folder/Positive/04356.jpg
# /content/unzipped_folder/Positive/08306.jpg
# /content/unzipped_folder/Positive/08741.jpg
# /content/unzipped_folder/Positive/01195.jpg
# /content/unzipped_folder/Positive/07247.jpg
# /content/unzipped_folder/Positive/03932.jpg
# /content/unzipped_folder/Positive/00512.jpg
# /content/unzipped_folder/Positive/07328.jpg
# /content/unzipped_folder/Positive/13564.jpg
# /content/unzipped_folder/Positive/11831.jpg
# /content/unzipped_folder/Positive/06169.jpg
# /content/unzipped_folder/Positive/12742.jpg
# /content/unzipped_folder/Positive/04870.jpg
# /content/unzipped_folder/Positive/06437.jpg
# /content/unzipped_folder/Positive/14165.jpg
# /content/unzipped_folder/Positive/02204.jpg
# /content/unzipped_folder/Positive/07733.jpg
# /content/unzipped_folder/Positive/12755.jpg
# /content/unzipped_folder/Positive/02800.jpg
# /content/unzipped_folder/Positive/08821.jpg
# /content/unzipped_folder/Positive/06320.jpg
# /content/unzipped_folder/Positive/08122.jpg
# /content/unzipped_folder/Positive/08137.jpg
# /content/unzipped_folder/Positive/12253.jpg
# /content/unzipped_folder/Positive/14492.jpg
# /content/unzipped_folder/Positive/13688.jpg
# /content/unzipped_folder/Positive/11902.jpg
# /content/unzipped_folder/Positive/03106.jpg
# /content/unzipped_folder/Positive/04004.jpg
# /content/unzipped_folder/Positive/02509.jpg
# /content/unzipped_folder/Positive/08670.jpg
# /content/unzipped_folder/Positive/08858.jpg
# /content/unzipped_folder/Positive/10817.jpg
# /content/unzipped_folder/Positive/10397.jpg
# /content/unzipped_folder/Positive/01941.jpg
# /content/unzipped_folder/Positive/01181.jpg
# /content/unzipped_folder/Positive/12827.jpg
# /content/unzipped_folder/Positive/06740.jpg
# /content/unzipped_folder/Positive/03594.jpg
# /content/unzipped_folder/Positive/12987.jpg
# /content/unzipped_folder/Positive/10860.jpg
# /content/unzipped_folder/Positive/11870.jpg
# /content/unzipped_folder/Positive/10604.jpg
# /content/unzipped_folder/Positive/00788.jpg
# /content/unzipped_folder/Positive/12117.jpg
# /content/unzipped_folder/Positive/03294.jpg
# /content/unzipped_folder/Positive/11706.jpg
# /content/unzipped_folder/Positive/00853.jpg
# /content/unzipped_folder/Positive/08488.jpg
# /content/unzipped_folder/Positive/04528.jpg
# /content/unzipped_folder/Positive/01123.jpg
# /content/unzipped_folder/Positive/08903.jpg
# /content/unzipped_folder/Positive/02865.jpg
# /content/unzipped_folder/Positive/08121.jpg
# /content/unzipped_folder/Positive/14996.jpg
# /content/unzipped_folder/Positive/01660.jpg
# /content/unzipped_folder/Positive/06909.jpg
# /content/unzipped_folder/Positive/04736.jpg
# /content/unzipped_folder/Positive/07643.jpg
# /content/unzipped_folder/Positive/10181.jpg
# /content/unzipped_folder/Positive/00497.jpg
# /content/unzipped_folder/Positive/11381.jpg
# /content/unzipped_folder/Positive/02821.jpg
# /content/unzipped_folder/Positive/01578.jpg
# /content/unzipped_folder/Positive/07254.jpg
# /content/unzipped_folder/Positive/11920.jpg
# /content/unzipped_folder/Positive/06828.jpg
# /content/unzipped_folder/Positive/05417.jpg
# /content/unzipped_folder/Positive/06725.jpg
# /content/unzipped_folder/Positive/05297.jpg
# /content/unzipped_folder/Positive/11444.jpg
# /content/unzipped_folder/Positive/12576.jpg
# /content/unzipped_folder/Positive/04514.jpg
# /content/unzipped_folder/Positive/02919.jpg
# /content/unzipped_folder/Positive/02795.jpg
# /content/unzipped_folder/Positive/06963.jpg
# /content/unzipped_folder/Positive/08618.jpg
# /content/unzipped_folder/Positive/01824.jpg
# /content/unzipped_folder/Positive/10754.jpg
# /content/unzipped_folder/Positive/00275.jpg
# /content/unzipped_folder/Positive/13220.jpg
# /content/unzipped_folder/Positive/14679.jpg
# /content/unzipped_folder/Positive/04504.jpg
# /content/unzipped_folder/Positive/03309.jpg
# /content/unzipped_folder/Positive/11976.jpg
# /content/unzipped_folder/Positive/05453.jpg
# /content/unzipped_folder/Positive/03147.jpg
# /content/unzipped_folder/Positive/13130.jpg
# /content/unzipped_folder/Positive/00803.jpg
# /content/unzipped_folder/Positive/05502.jpg
# /content/unzipped_folder/Positive/10588.jpg
# /content/unzipped_folder/Positive/09568.jpg
# /content/unzipped_folder/Positive/08831.jpg
# /content/unzipped_folder/Positive/03886.jpg
# /content/unzipped_folder/Positive/14908.jpg
# /content/unzipped_folder/Positive/09255.jpg
# /content/unzipped_folder/Positive/00880.jpg
# /content/unzipped_folder/Positive/05822.jpg
# /content/unzipped_folder/Positive/03654.jpg
# /content/unzipped_folder/Positive/05733.jpg
# /content/unzipped_folder/Positive/04756.jpg
# /content/unzipped_folder/Positive/14650.jpg
# /content/unzipped_folder/Positive/12302.jpg
# /content/unzipped_folder/Positive/12286.jpg
# /content/unzipped_folder/Positive/11112.jpg
# /content/unzipped_folder/Positive/03151.jpg
# /content/unzipped_folder/Positive/03650.jpg
# /content/unzipped_folder/Positive/13804.jpg
# /content/unzipped_folder/Positive/10128.jpg
# /content/unzipped_folder/Positive/14082.jpg
# /content/unzipped_folder/Positive/02866.jpg
# /content/unzipped_folder/Positive/13743.jpg
# /content/unzipped_folder/Positive/11466.jpg
# /content/unzipped_folder/Positive/11046.jpg
# /content/unzipped_folder/Positive/06833.jpg
# /content/unzipped_folder/Positive/09759.jpg
# /content/unzipped_folder/Positive/05966.jpg
# /content/unzipped_folder/Positive/08049.jpg
# /content/unzipped_folder/Positive/01026.jpg
# /content/unzipped_folder/Positive/01726.jpg
# /content/unzipped_folder/Positive/14941.jpg
# /content/unzipped_folder/Positive/00732.jpg
# /content/unzipped_folder/Positive/07120.jpg
# /content/unzipped_folder/Positive/08099.jpg
# /content/unzipped_folder/Positive/07280.jpg
# /content/unzipped_folder/Positive/12095.jpg
# /content/unzipped_folder/Positive/02842.jpg
# /content/unzipped_folder/Positive/13176.jpg
# /content/unzipped_folder/Positive/12394.jpg
# /content/unzipped_folder/Positive/14937.jpg
# /content/unzipped_folder/Positive/00123.jpg
# /content/unzipped_folder/Positive/14124.jpg
# /content/unzipped_folder/Positive/11292.jpg
# /content/unzipped_folder/Positive/06142.jpg
# /content/unzipped_folder/Positive/11402.jpg
# /content/unzipped_folder/Positive/00743.jpg
# /content/unzipped_folder/Positive/08424.jpg
# /content/unzipped_folder/Positive/12978.jpg
# /content/unzipped_folder/Positive/06471.jpg
# /content/unzipped_folder/Positive/05001.jpg
# /content/unzipped_folder/Positive/01821.jpg
# /content/unzipped_folder/Positive/11805.jpg
# /content/unzipped_folder/Positive/05946.jpg
# /content/unzipped_folder/Positive/11948.jpg
# /content/unzipped_folder/Positive/04895.jpg
# /content/unzipped_folder/Positive/09691.jpg
# /content/unzipped_folder/Positive/14389.jpg
# /content/unzipped_folder/Positive/09333.jpg
# /content/unzipped_folder/Positive/00801.jpg
# /content/unzipped_folder/Positive/02301.jpg
# /content/unzipped_folder/Positive/00386.jpg
# /content/unzipped_folder/Positive/07251.jpg
# /content/unzipped_folder/Positive/08948.jpg
# /content/unzipped_folder/Positive/10195.jpg
# /content/unzipped_folder/Positive/10700.jpg
# /content/unzipped_folder/Positive/06872.jpg
# /content/unzipped_folder/Positive/12401.jpg
# /content/unzipped_folder/Positive/03009.jpg
# /content/unzipped_folder/Positive/03467.jpg
# /content/unzipped_folder/Positive/02069.jpg
# /content/unzipped_folder/Positive/01310.jpg
# /content/unzipped_folder/Positive/08860.jpg
# /content/unzipped_folder/Positive/05325.jpg
# /content/unzipped_folder/Positive/09631.jpg
# /content/unzipped_folder/Positive/10851.jpg
# /content/unzipped_folder/Positive/03804.jpg
# /content/unzipped_folder/Positive/11131.jpg
# /content/unzipped_folder/Positive/00766.jpg
# /content/unzipped_folder/Positive/14078.jpg
# /content/unzipped_folder/Positive/06701.jpg
# /content/unzipped_folder/Positive/05858.jpg
# /content/unzipped_folder/Positive/09677.jpg
# /content/unzipped_folder/Positive/12916.jpg
# /content/unzipped_folder/Positive/05202.jpg
# /content/unzipped_folder/Positive/14008.jpg
# /content/unzipped_folder/Positive/04693.jpg
# /content/unzipped_folder/Positive/04609.jpg
# /content/unzipped_folder/Positive/09795.jpg
# /content/unzipped_folder/Positive/12582.jpg
# /content/unzipped_folder/Positive/09251.jpg
# /content/unzipped_folder/Positive/10545.jpg
# /content/unzipped_folder/Positive/13496.jpg
# /content/unzipped_folder/Positive/03336.jpg
# /content/unzipped_folder/Positive/07255.jpg
# /content/unzipped_folder/Positive/05073.jpg
# /content/unzipped_folder/Positive/13126.jpg
# /content/unzipped_folder/Positive/09775.jpg
# /content/unzipped_folder/Positive/05043.jpg
# /content/unzipped_folder/Positive/14226.jpg
# /content/unzipped_folder/Positive/14181.jpg
# /content/unzipped_folder/Positive/06784.jpg
# /content/unzipped_folder/Positive/14834.jpg
# /content/unzipped_folder/Positive/08216.jpg
# /content/unzipped_folder/Positive/12361.jpg
# /content/unzipped_folder/Positive/07467.jpg
# /content/unzipped_folder/Positive/07636.jpg
# /content/unzipped_folder/Positive/04646.jpg
# /content/unzipped_folder/Positive/07179.jpg
# /content/unzipped_folder/Positive/04547.jpg
# /content/unzipped_folder/Positive/09732.jpg
# /content/unzipped_folder/Positive/01846.jpg
# /content/unzipped_folder/Positive/10742.jpg
# /content/unzipped_folder/Positive/13676.jpg
# /content/unzipped_folder/Positive/08545.jpg
# /content/unzipped_folder/Positive/02774.jpg
# /content/unzipped_folder/Positive/13863.jpg
# /content/unzipped_folder/Positive/10266.jpg
# /content/unzipped_folder/Positive/10063.jpg
# /content/unzipped_folder/Positive/01087.jpg
# /content/unzipped_folder/Positive/00683.jpg
# /content/unzipped_folder/Positive/12446.jpg
# /content/unzipped_folder/Positive/00592.jpg
# /content/unzipped_folder/Positive/12469.jpg
# /content/unzipped_folder/Positive/03264.jpg
# /content/unzipped_folder/Positive/12237.jpg
# /content/unzipped_folder/Positive/05986.jpg
# /content/unzipped_folder/Positive/12593.jpg
# /content/unzipped_folder/Positive/01393.jpg
# /content/unzipped_folder/Positive/07776.jpg
# /content/unzipped_folder/Positive/08437.jpg
# /content/unzipped_folder/Positive/14791.jpg
# /content/unzipped_folder/Positive/03628.jpg
# /content/unzipped_folder/Positive/03528.jpg
# /content/unzipped_folder/Positive/13162.jpg
# /content/unzipped_folder/Positive/01923.jpg
# /content/unzipped_folder/Positive/12677.jpg
# /content/unzipped_folder/Positive/09652.jpg
# /content/unzipped_folder/Positive/01593.jpg
# /content/unzipped_folder/Positive/06056.jpg
# /content/unzipped_folder/Positive/01211.jpg
# /content/unzipped_folder/Positive/00555.jpg
# /content/unzipped_folder/Positive/03742.jpg
# /content/unzipped_folder/Positive/14672.jpg
# /content/unzipped_folder/Positive/11011.jpg
# /content/unzipped_folder/Positive/12118.jpg
# /content/unzipped_folder/Positive/09240.jpg
# /content/unzipped_folder/Positive/00568.jpg
# /content/unzipped_folder/Positive/08504.jpg
# /content/unzipped_folder/Positive/01053.jpg
# /content/unzipped_folder/Positive/13836.jpg
# /content/unzipped_folder/Positive/11135.jpg
# /content/unzipped_folder/Positive/14432.jpg
# /content/unzipped_folder/Positive/06936.jpg
# /content/unzipped_folder/Positive/14021.jpg
# /content/unzipped_folder/Positive/05044.jpg
# /content/unzipped_folder/Positive/03749.jpg
# /content/unzipped_folder/Positive/09943.jpg
# /content/unzipped_folder/Positive/11917.jpg
# /content/unzipped_folder/Positive/07140.jpg
# /content/unzipped_folder/Positive/09014.jpg
# /content/unzipped_folder/Positive/00421.jpg
# /content/unzipped_folder/Positive/02177.jpg
# /content/unzipped_folder/Positive/11163.jpg
# /content/unzipped_folder/Positive/03409.jpg
# /content/unzipped_folder/Positive/01415.jpg
# /content/unzipped_folder/Positive/14448.jpg
# /content/unzipped_folder/Positive/03332.jpg
# /content/unzipped_folder/Positive/13996.jpg
# /content/unzipped_folder/Positive/01757.jpg
# /content/unzipped_folder/Positive/13452.jpg
# /content/unzipped_folder/Positive/09936.jpg
# /content/unzipped_folder/Positive/10564.jpg
# /content/unzipped_folder/Positive/11882.jpg
# /content/unzipped_folder/Positive/10745.jpg
# /content/unzipped_folder/Positive/07825.jpg
# /content/unzipped_folder/Positive/08443.jpg
# /content/unzipped_folder/Positive/12036.jpg
# /content/unzipped_folder/Positive/05106.jpg
# /content/unzipped_folder/Positive/04155.jpg
# /content/unzipped_folder/Positive/07426.jpg
# /content/unzipped_folder/Positive/14565.jpg
# /content/unzipped_folder/Positive/12459.jpg
# /content/unzipped_folder/Positive/09684.jpg
# /content/unzipped_folder/Positive/02411.jpg
# /content/unzipped_folder/Positive/02847.jpg
# /content/unzipped_folder/Positive/12240.jpg
# /content/unzipped_folder/Positive/12285.jpg
# /content/unzipped_folder/Positive/09458.jpg
# /content/unzipped_folder/Positive/03444.jpg
# /content/unzipped_folder/Positive/01709.jpg
# /content/unzipped_folder/Positive/10610.jpg
# /content/unzipped_folder/Positive/06090.jpg
# /content/unzipped_folder/Positive/11067.jpg
# /content/unzipped_folder/Positive/10465.jpg
# /content/unzipped_folder/Positive/06857.jpg
# /content/unzipped_folder/Positive/14423.jpg
# /content/unzipped_folder/Positive/08762.jpg
# /content/unzipped_folder/Positive/10663.jpg
# /content/unzipped_folder/Positive/01753.jpg
# /content/unzipped_folder/Positive/01711.jpg
# /content/unzipped_folder/Positive/05978.jpg
# /content/unzipped_folder/Positive/14920.jpg
# /content/unzipped_folder/Positive/09702.jpg
# /content/unzipped_folder/Positive/03687.jpg
# /content/unzipped_folder/Positive/12893.jpg
# /content/unzipped_folder/Positive/10526.jpg
# /content/unzipped_folder/Positive/08531.jpg
# /content/unzipped_folder/Positive/03369.jpg
# /content/unzipped_folder/Positive/12612.jpg
# /content/unzipped_folder/Positive/11762.jpg
# /content/unzipped_folder/Positive/00956.jpg
# /content/unzipped_folder/Positive/06679.jpg
# /content/unzipped_folder/Positive/05113.jpg
# /content/unzipped_folder/Positive/02802.jpg
# /content/unzipped_folder/Positive/11933.jpg
# /content/unzipped_folder/Positive/08476.jpg
# /content/unzipped_folder/Positive/14318.jpg
# /content/unzipped_folder/Positive/04591.jpg
# /content/unzipped_folder/Positive/09261.jpg
# /content/unzipped_folder/Positive/00037.jpg
# /content/unzipped_folder/Positive/02569.jpg
# /content/unzipped_folder/Positive/11610.jpg
# /content/unzipped_folder/Positive/03844.jpg
# /content/unzipped_folder/Positive/14552.jpg
# /content/unzipped_folder/Positive/06852.jpg
# /content/unzipped_folder/Positive/02474.jpg
# /content/unzipped_folder/Positive/11943.jpg
# /content/unzipped_folder/Positive/02405.jpg
# /content/unzipped_folder/Positive/01329.jpg
# /content/unzipped_folder/Positive/09170.jpg
# /content/unzipped_folder/Positive/03189.jpg
# /content/unzipped_folder/Positive/10547.jpg
# /content/unzipped_folder/Positive/11642.jpg
# /content/unzipped_folder/Positive/13345.jpg
# /content/unzipped_folder/Positive/11545.jpg
# /content/unzipped_folder/Positive/14505.jpg
# /content/unzipped_folder/Positive/05081.jpg
# /content/unzipped_folder/Positive/03806.jpg
# /content/unzipped_folder/Positive/10688.jpg
# /content/unzipped_folder/Positive/10064.jpg
# /content/unzipped_folder/Positive/05516.jpg
# /content/unzipped_folder/Positive/06054.jpg
# /content/unzipped_folder/Positive/09414.jpg
# /content/unzipped_folder/Positive/11503.jpg
# /content/unzipped_folder/Positive/12215.jpg
# /content/unzipped_folder/Positive/10804.jpg
# /content/unzipped_folder/Positive/13835.jpg
# /content/unzipped_folder/Positive/14556.jpg
# /content/unzipped_folder/Positive/03936.jpg
# /content/unzipped_folder/Positive/10309.jpg
# /content/unzipped_folder/Positive/08036.jpg
# /content/unzipped_folder/Positive/07071.jpg
# /content/unzipped_folder/Positive/08834.jpg
# /content/unzipped_folder/Positive/11007.jpg
# /content/unzipped_folder/Positive/04505.jpg
# /content/unzipped_folder/Positive/00323.jpg
# /content/unzipped_folder/Positive/04725.jpg
# /content/unzipped_folder/Positive/11753.jpg
# /content/unzipped_folder/Positive/08617.jpg
# /content/unzipped_folder/Positive/14664.jpg
# /content/unzipped_folder/Positive/03879.jpg
# /content/unzipped_folder/Positive/12454.jpg
# /content/unzipped_folder/Positive/07865.jpg
# /content/unzipped_folder/Positive/06227.jpg
# /content/unzipped_folder/Positive/00755.jpg
# /content/unzipped_folder/Positive/02691.jpg
# /content/unzipped_folder/Positive/06205.jpg
# /content/unzipped_folder/Positive/11068.jpg
# /content/unzipped_folder/Positive/12219.jpg
# /content/unzipped_folder/Positive/10187.jpg
# /content/unzipped_folder/Positive/12055.jpg
# /content/unzipped_folder/Positive/07971.jpg
# /content/unzipped_folder/Positive/01274.jpg
# /content/unzipped_folder/Positive/03829.jpg
# /content/unzipped_folder/Positive/09321.jpg
# /content/unzipped_folder/Positive/05596.jpg
# /content/unzipped_folder/Positive/00729.jpg
# /content/unzipped_folder/Positive/14931.jpg
# /content/unzipped_folder/Positive/07639.jpg
# /content/unzipped_folder/Positive/01359.jpg
# /content/unzipped_folder/Positive/04493.jpg
# /content/unzipped_folder/Positive/14833.jpg
# ...
# /content/unzipped_folder/Positive/08757.jpg
# /content/unzipped_folder/Positive/10612.jpg
# /content/unzipped_folder/Positive/05282.jpg
# /content/unzipped_folder/Positive/09887.jpg
# /content/unzipped_folder/Positive/09313.jpg
# /content/unzipped_folder/Positive/06819.jpg
# /content/unzipped_folder/Positive/10661.jpg
# /content/unzipped_folder/Positive/05983.jpg
# /content/unzipped_folder/Positive/12813.jpg
# /content/unzipped_folder/Positive/03750.jpg
# /content/unzipped_folder/Positive/11377.jpg
# /content/unzipped_folder/Positive/12551.jpg
# /content/unzipped_folder/Positive/05918.jpg
# /content/unzipped_folder/Positive/01224.jpg
# /content/unzipped_folder/Positive/06942.jpg
# /content/unzipped_folder/Positive/08655.jpg
# /content/unzipped_folder/Positive/03596.jpg
# /content/unzipped_folder/Positive/02480.jpg
# /content/unzipped_folder/Positive/06203.jpg
# /content/unzipped_folder/Positive/01364.jpg
# /content/unzipped_folder/Positive/10961.jpg
# /content/unzipped_folder/Positive/10182.jpg
# /content/unzipped_folder/Positive/11832.jpg
# /content/unzipped_folder/Positive/02741.jpg
# /content/unzipped_folder/Positive/00235.jpg
# /content/unzipped_folder/Positive/10946.jpg
# /content/unzipped_folder/Positive/05336.jpg
# /content/unzipped_folder/Positive/10531.jpg
# /content/unzipped_folder/Positive/10802.jpg
# /content/unzipped_folder/Positive/00739.jpg
# /content/unzipped_folder/Positive/12923.jpg
# /content/unzipped_folder/Positive/13403.jpg
# /content/unzipped_folder/Positive/00489.jpg
# /content/unzipped_folder/Positive/09024.jpg
# /content/unzipped_folder/Positive/13351.jpg
# /content/unzipped_folder/Positive/12712.jpg
# /content/unzipped_folder/Positive/01511.jpg
# /content/unzipped_folder/Positive/11186.jpg
# /content/unzipped_folder/Positive/14183.jpg
# /content/unzipped_folder/Positive/08602.jpg
# /content/unzipped_folder/Positive/02505.jpg
# /content/unzipped_folder/Positive/13818.jpg
# /content/unzipped_folder/Positive/06213.jpg
# /content/unzipped_folder/Positive/04913.jpg
# /content/unzipped_folder/Positive/00191.jpg
# /content/unzipped_folder/Positive/10020.jpg
# /content/unzipped_folder/Positive/04235.jpg
# /content/unzipped_folder/Positive/05707.jpg
# /content/unzipped_folder/Positive/08283.jpg
# /content/unzipped_folder/Positive/08250.jpg
# /content/unzipped_folder/Positive/11056.jpg
# /content/unzipped_folder/Positive/09700.jpg
# /content/unzipped_folder/Positive/09973.jpg
# /content/unzipped_folder/Positive/11723.jpg
# /content/unzipped_folder/Positive/09456.jpg
# /content/unzipped_folder/Positive/05513.jpg
# /content/unzipped_folder/Positive/01622.jpg
# /content/unzipped_folder/Positive/02996.jpg
# /content/unzipped_folder/Positive/01056.jpg
# /content/unzipped_folder/Positive/09383.jpg
# /content/unzipped_folder/Positive/11177.jpg
# /content/unzipped_folder/Positive/08786.jpg
# /content/unzipped_folder/Positive/14372.jpg
# /content/unzipped_folder/Positive/04695.jpg
# /content/unzipped_folder/Positive/00604.jpg
# /content/unzipped_folder/Positive/13545.jpg
# /content/unzipped_folder/Positive/01618.jpg
# /content/unzipped_folder/Positive/08288.jpg
# /content/unzipped_folder/Positive/14223.jpg
# /content/unzipped_folder/Positive/03634.jpg
# /content/unzipped_folder/Positive/11510.jpg
# /content/unzipped_folder/Positive/00113.jpg
# /content/unzipped_folder/Positive/11330.jpg
# /content/unzipped_folder/Positive/09508.jpg
# /content/unzipped_folder/Positive/13252.jpg
# /content/unzipped_folder/Positive/12917.jpg
# /content/unzipped_folder/Positive/06808.jpg
# /content/unzipped_folder/Positive/01072.jpg
# /content/unzipped_folder/Positive/00200.jpg
# /content/unzipped_folder/Positive/06937.jpg
# /content/unzipped_folder/Positive/04751.jpg
# /content/unzipped_folder/Positive/00401.jpg
# /content/unzipped_folder/Positive/10643.jpg
# /content/unzipped_folder/Positive/06504.jpg
# /content/unzipped_folder/Positive/07706.jpg
# /content/unzipped_folder/Positive/02743.jpg
# /content/unzipped_folder/Positive/06678.jpg
# /content/unzipped_folder/Positive/01048.jpg
# /content/unzipped_folder/Positive/07607.jpg
# /content/unzipped_folder/Positive/12281.jpg
# /content/unzipped_folder/Positive/01424.jpg
# /content/unzipped_folder/Positive/13024.jpg
# /content/unzipped_folder/Positive/11793.jpg
# /content/unzipped_folder/Positive/09037.jpg
# /content/unzipped_folder/Positive/14855.jpg
# /content/unzipped_folder/Positive/07919.jpg
# /content/unzipped_folder/Positive/10869.jpg
# /content/unzipped_folder/Positive/09192.jpg
# /content/unzipped_folder/Positive/03284.jpg
# /content/unzipped_folder/Positive/12171.jpg
# /content/unzipped_folder/Positive/02514.jpg
# /content/unzipped_folder/Positive/09592.jpg
# /content/unzipped_folder/Positive/04350.jpg
# /content/unzipped_folder/Positive/02728.jpg
# /content/unzipped_folder/Positive/09315.jpg
# /content/unzipped_folder/Positive/02518.jpg
# /content/unzipped_folder/Positive/08340.jpg
# /content/unzipped_folder/Positive/11919.jpg
# /content/unzipped_folder/Positive/06243.jpg
# /content/unzipped_folder/Positive/10896.jpg
# /content/unzipped_folder/Positive/14006.jpg
# /content/unzipped_folder/Positive/10222.jpg
# /content/unzipped_folder/Positive/03992.jpg
# /content/unzipped_folder/Positive/03543.jpg
# /content/unzipped_folder/Positive/02154.jpg
# /content/unzipped_folder/Positive/07295.jpg
# /content/unzipped_folder/Positive/05569.jpg
# /content/unzipped_folder/Positive/11097.jpg
# /content/unzipped_folder/Positive/13096.jpg
# /content/unzipped_folder/Positive/12943.jpg
# /content/unzipped_folder/Positive/08182.jpg
# /content/unzipped_folder/Positive/13969.jpg
# /content/unzipped_folder/Positive/03488.jpg
# /content/unzipped_folder/Positive/09884.jpg
# /content/unzipped_folder/Positive/01241.jpg
# /content/unzipped_folder/Positive/02050.jpg
# /content/unzipped_folder/Positive/05004.jpg
# /content/unzipped_folder/Positive/07881.jpg
# /content/unzipped_folder/Positive/03535.jpg
# /content/unzipped_folder/Positive/02901.jpg
# /content/unzipped_folder/Positive/12901.jpg
# /content/unzipped_folder/Positive/06669.jpg
# /content/unzipped_folder/Positive/14324.jpg
# /content/unzipped_folder/Positive/10246.jpg
# /content/unzipped_folder/Positive/13711.jpg
# /content/unzipped_folder/Positive/12500.jpg
# /content/unzipped_folder/Positive/04983.jpg
# /content/unzipped_folder/Positive/01298.jpg
# /content/unzipped_folder/Positive/13267.jpg
# /content/unzipped_folder/Positive/12971.jpg
# /content/unzipped_folder/Positive/06972.jpg
# /content/unzipped_folder/Positive/02003.jpg
# /content/unzipped_folder/Positive/14166.jpg
# /content/unzipped_folder/Positive/02429.jpg
# /content/unzipped_folder/Positive/01098.jpg
# /content/unzipped_folder/Positive/08529.jpg
# /content/unzipped_folder/Positive/14302.jpg
# /content/unzipped_folder/Positive/14024.jpg
# /content/unzipped_folder/Positive/06611.jpg
# /content/unzipped_folder/Positive/13805.jpg
# /content/unzipped_folder/Positive/01487.jpg
# /content/unzipped_folder/Positive/02486.jpg
# /content/unzipped_folder/Positive/13074.jpg
# /content/unzipped_folder/Positive/09283.jpg
# /content/unzipped_folder/Positive/12973.jpg
# /content/unzipped_folder/Positive/07725.jpg
# /content/unzipped_folder/Positive/00872.jpg
# /content/unzipped_folder/Positive/14682.jpg
# /content/unzipped_folder/Positive/07018.jpg
# /content/unzipped_folder/Positive/07821.jpg
# /content/unzipped_folder/Positive/00168.jpg
# /content/unzipped_folder/Positive/10968.jpg
# /content/unzipped_folder/Positive/04868.jpg
# /content/unzipped_folder/Positive/05600.jpg
# /content/unzipped_folder/Positive/07987.jpg
# /content/unzipped_folder/Positive/01532.jpg
# /content/unzipped_folder/Positive/07786.jpg
# /content/unzipped_folder/Positive/14542.jpg
# /content/unzipped_folder/Positive/01397.jpg
# /content/unzipped_folder/Positive/02690.jpg
# /content/unzipped_folder/Positive/04813.jpg
# /content/unzipped_folder/Positive/08149.jpg
# /content/unzipped_folder/Positive/05999.jpg
# /content/unzipped_folder/Positive/08446.jpg
# /content/unzipped_folder/Positive/13416.jpg
# /content/unzipped_folder/Positive/01740.jpg
# /content/unzipped_folder/Positive/14418.jpg
# /content/unzipped_folder/Positive/11375.jpg
# /content/unzipped_folder/Positive/05174.jpg
# /content/unzipped_folder/Positive/06046.jpg
# /content/unzipped_folder/Positive/11641.jpg
# /content/unzipped_folder/Positive/02948.jpg
# /content/unzipped_folder/Positive/13530.jpg
# /content/unzipped_folder/Positive/06273.jpg
# /content/unzipped_folder/Positive/01485.jpg
# /content/unzipped_folder/Positive/10710.jpg
# /content/unzipped_folder/Positive/03574.jpg
# /content/unzipped_folder/Positive/09460.jpg
# /content/unzipped_folder/Positive/04196.jpg
# /content/unzipped_folder/Positive/13501.jpg
# /content/unzipped_folder/Positive/01619.jpg
# /content/unzipped_folder/Positive/03097.jpg
# /content/unzipped_folder/Positive/04662.jpg
# /content/unzipped_folder/Positive/08022.jpg
# /content/unzipped_folder/Positive/11242.jpg
# /content/unzipped_folder/Positive/06760.jpg
# /content/unzipped_folder/Positive/12832.jpg
# /content/unzipped_folder/Positive/13518.jpg
# /content/unzipped_folder/Positive/07109.jpg
# /content/unzipped_folder/Positive/14532.jpg
# /content/unzipped_folder/Positive/12564.jpg
# /content/unzipped_folder/Positive/06925.jpg
# /content/unzipped_folder/Positive/03338.jpg
# /content/unzipped_folder/Positive/13590.jpg
# /content/unzipped_folder/Positive/01266.jpg
# /content/unzipped_folder/Positive/07453.jpg
# /content/unzipped_folder/Positive/08959.jpg
# /content/unzipped_folder/Positive/02588.jpg
# /content/unzipped_folder/Positive/05810.jpg
# /content/unzipped_folder/Positive/05023.jpg
# /content/unzipped_folder/Positive/11435.jpg
# /content/unzipped_folder/Positive/03262.jpg
# /content/unzipped_folder/Positive/05968.jpg
# /content/unzipped_folder/Positive/13577.jpg
# /content/unzipped_folder/Positive/01961.jpg
# /content/unzipped_folder/Positive/07190.jpg
# /content/unzipped_folder/Positive/06382.jpg
# /content/unzipped_folder/Positive/02876.jpg
# /content/unzipped_folder/Positive/11274.jpg
# /content/unzipped_folder/Positive/11953.jpg
# /content/unzipped_folder/Positive/03990.jpg
# /content/unzipped_folder/Positive/14193.jpg
# /content/unzipped_folder/Positive/09982.jpg
# /content/unzipped_folder/Positive/01116.jpg
# /content/unzipped_folder/Positive/02959.jpg
# /content/unzipped_folder/Positive/04134.jpg
# /content/unzipped_folder/Positive/07735.jpg
# /content/unzipped_folder/Positive/10024.jpg
# /content/unzipped_folder/Positive/04711.jpg
# /content/unzipped_folder/Positive/03561.jpg
# /content/unzipped_folder/Positive/13062.jpg
# /content/unzipped_folder/Positive/07721.jpg
# /content/unzipped_folder/Positive/14216.jpg
# /content/unzipped_folder/Positive/10805.jpg
# /content/unzipped_folder/Positive/11200.jpg
# /content/unzipped_folder/Positive/04955.jpg
# /content/unzipped_folder/Positive/06641.jpg
# /content/unzipped_folder/Positive/08237.jpg
# /content/unzipped_folder/Positive/07948.jpg
# /content/unzipped_folder/Positive/01353.jpg
# /content/unzipped_folder/Positive/13737.jpg
# /content/unzipped_folder/Positive/03479.jpg
# /content/unzipped_folder/Positive/13027.jpg
# /content/unzipped_folder/Positive/10727.jpg
# /content/unzipped_folder/Positive/08530.jpg
# /content/unzipped_folder/Positive/06201.jpg
# /content/unzipped_folder/Positive/09543.jpg
# /content/unzipped_folder/Positive/13692.jpg
# /content/unzipped_folder/Positive/11031.jpg
# /content/unzipped_folder/Positive/01940.jpg
# /content/unzipped_folder/Positive/12656.jpg
# /content/unzipped_folder/Positive/02822.jpg
# /content/unzipped_folder/Positive/04525.jpg
# /content/unzipped_folder/Positive/08587.jpg
# /content/unzipped_folder/Positive/00020.jpg
# /content/unzipped_folder/Positive/08812.jpg
# /content/unzipped_folder/Positive/09581.jpg
# /content/unzipped_folder/Positive/04754.jpg
# /content/unzipped_folder/Positive/11843.jpg
# /content/unzipped_folder/Positive/13716.jpg
# /content/unzipped_folder/Positive/11173.jpg
# /content/unzipped_folder/Positive/10293.jpg
# /content/unzipped_folder/Positive/12621.jpg
# /content/unzipped_folder/Positive/01823.jpg
# /content/unzipped_folder/Positive/14283.jpg
# /content/unzipped_folder/Positive/12798.jpg
# /content/unzipped_folder/Positive/09876.jpg
# /content/unzipped_folder/Positive/13766.jpg
# /content/unzipped_folder/Positive/05812.jpg
# /content/unzipped_folder/Positive/01286.jpg
# /content/unzipped_folder/Positive/13171.jpg
# /content/unzipped_folder/Positive/01333.jpg
# /content/unzipped_folder/Positive/12559.jpg
# /content/unzipped_folder/Positive/09084.jpg
# /content/unzipped_folder/Positive/11062.jpg
# /content/unzipped_folder/Positive/13128.jpg
# /content/unzipped_folder/Positive/06047.jpg
# /content/unzipped_folder/Positive/04088.jpg
# /content/unzipped_folder/Positive/08401.jpg
# /content/unzipped_folder/Positive/11373.jpg
# /content/unzipped_folder/Positive/06079.jpg
# /content/unzipped_folder/Positive/02601.jpg
# /content/unzipped_folder/Positive/09945.jpg
# /content/unzipped_folder/Positive/09152.jpg
# /content/unzipped_folder/Positive/10202.jpg
# /content/unzipped_folder/Positive/07346.jpg
# /content/unzipped_folder/Positive/10204.jpg
# /content/unzipped_folder/Positive/05266.jpg
# /content/unzipped_folder/Positive/13814.jpg
# /content/unzipped_folder/Positive/01647.jpg
# /content/unzipped_folder/Positive/00734.jpg
# /content/unzipped_folder/Positive/13427.jpg
# /content/unzipped_folder/Positive/04072.jpg
# /content/unzipped_folder/Positive/01909.jpg
# /content/unzipped_folder/Positive/04283.jpg
# /content/unzipped_folder/Positive/00971.jpg
# /content/unzipped_folder/Positive/09882.jpg
# /content/unzipped_folder/Positive/04265.jpg
# /content/unzipped_folder/Positive/07594.jpg
# /content/unzipped_folder/Positive/02207.jpg
# /content/unzipped_folder/Positive/11970.jpg
# /content/unzipped_folder/Positive/12370.jpg
# /content/unzipped_folder/Positive/02773.jpg
# /content/unzipped_folder/Positive/08076.jpg
# /content/unzipped_folder/Positive/07393.jpg
# /content/unzipped_folder/Positive/01297.jpg
# /content/unzipped_folder/Positive/05984.jpg
# /content/unzipped_folder/Positive/14930.jpg
# /content/unzipped_folder/Positive/13402.jpg
# /content/unzipped_folder/Positive/04162.jpg
# /content/unzipped_folder/Positive/07810.jpg
# /content/unzipped_folder/Positive/08999.jpg
# /content/unzipped_folder/Positive/11700.jpg
# /content/unzipped_folder/Positive/09166.jpg
# /content/unzipped_folder/Positive/06729.jpg
# /content/unzipped_folder/Positive/06673.jpg
# /content/unzipped_folder/Positive/09186.jpg
# /content/unzipped_folder/Positive/08110.jpg
# /content/unzipped_folder/Positive/10553.jpg
# /content/unzipped_folder/Positive/09493.jpg
# /content/unzipped_folder/Positive/14578.jpg
# /content/unzipped_folder/Positive/03739.jpg
# /content/unzipped_folder/Positive/09345.jpg
# /content/unzipped_folder/Positive/00021.jpg
# /content/unzipped_folder/Positive/10252.jpg
# /content/unzipped_folder/Positive/04511.jpg
# /content/unzipped_folder/Positive/09689.jpg
# /content/unzipped_folder/Positive/05997.jpg
# /content/unzipped_folder/Positive/10513.jpg
# /content/unzipped_folder/Positive/02158.jpg
# /content/unzipped_folder/Positive/01583.jpg
# /content/unzipped_folder/Positive/04092.jpg
# /content/unzipped_folder/Positive/10859.jpg
# /content/unzipped_folder/Positive/00535.jpg
# /content/unzipped_folder/Positive/08436.jpg
# /content/unzipped_folder/Positive/12067.jpg
# /content/unzipped_folder/Positive/08892.jpg
# /content/unzipped_folder/Positive/08918.jpg
# /content/unzipped_folder/Positive/05180.jpg
# /content/unzipped_folder/Positive/14698.jpg
# /content/unzipped_folder/Positive/12557.jpg
# /content/unzipped_folder/Positive/03944.jpg
# /content/unzipped_folder/Positive/00771.jpg
# /content/unzipped_folder/Positive/07064.jpg
# /content/unzipped_folder/Positive/06211.jpg
# /content/unzipped_folder/Positive/03617.jpg
# /content/unzipped_folder/Positive/08687.jpg
# /content/unzipped_folder/Positive/11514.jpg
# /content/unzipped_folder/Positive/02632.jpg
# /content/unzipped_folder/Positive/03366.jpg
# /content/unzipped_folder/Positive/10986.jpg
# /content/unzipped_folder/Positive/11247.jpg
# /content/unzipped_folder/Positive/09511.jpg
# /content/unzipped_folder/Positive/08665.jpg
# /content/unzipped_folder/Positive/04432.jpg
# /content/unzipped_folder/Positive/03589.jpg
# /content/unzipped_folder/Positive/11262.jpg
# /content/unzipped_folder/Positive/08740.jpg
# /content/unzipped_folder/Positive/03005.jpg
# /content/unzipped_folder/Positive/00390.jpg
# /content/unzipped_folder/Positive/12013.jpg
# /content/unzipped_folder/Positive/12769.jpg
# /content/unzipped_folder/Positive/05601.jpg

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
from scipy.stats import f_oneway, norm, chi2_contingency
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- 1. Paths and Constants ---
base_dir = "/content/unzipped_folder"  # Adjust this if needed
IMG_SIZE = (128, 128)
BATCH_SIZE = 32

# --- 2. Image Data Generator ---
datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training",
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    base_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation",
    shuffle=True
)

# --- 3. Extract a Batch ---
X_batch, y_batch = next(train_generator)

# --- 4. Separate Cracked and Uncracked Images ---
cracked_data = [(img, int(label)) for img, label in zip(X_batch, y_batch) if label == 1]
uncracked_data = [(img, int(label)) for img, label in zip(X_batch, y_batch) if label == 0]

# Combine and shuffle
all_data = cracked_data + uncracked_data
np.random.shuffle(all_data)

images = [img for img, label in all_data]
labels = [label for img, label in all_data]

# --- 5. Show Sample Images ---
plt.figure(figsize=(10, 5))
for i in range(3):
    plt.subplot(2, 3, i + 1)
    plt.imshow(cracked_data[i][0])
    plt.title("Cracked")
    plt.axis('off')

    plt.subplot(2, 3, i + 4)
    plt.imshow(uncracked_data[i][0])
    plt.title("Uncracked")
    plt.axis('off')
plt.tight_layout()
plt.show()

# --- 6. Mean Pixel Intensities ---
cracked_means = [np.mean(img) for img, label in cracked_data]
uncracked_means = [np.mean(img) for img, label in uncracked_data]

# --- 7. ANOVA TEST ---
anova_stat, anova_p = f_oneway(cracked_means, uncracked_means)
print(f"\nANOVA Test:")
print(f"F-statistic: {anova_stat:.4f}")
print(f"P-value: {anova_p:.4f}")
if anova_p < 0.05:
    print("=> Statistically significant difference between cracked and uncracked images.\n")
else:
    print("=> No significant difference between the two classes.\n")

# --- 8. Distribution Plot (ANOVA Visualization) ---
plt.figure(figsize=(8, 6))
sns.kdeplot(cracked_means, label="Cracked", fill=True)
sns.kdeplot(uncracked_means, label="Uncracked", fill=True)
plt.title("Grayscale Mean Intensity Distribution")
plt.xlabel("Mean Pixel Intensity")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()

# --- Box Plot ---
plt.figure(figsize=(8, 6))
sns.boxplot(data=[cracked_means, uncracked_means], palette=["salmon", "lightgreen"])
plt.xticks([0, 1], ["Cracked", "Uncracked"])
plt.title("Boxplot of Mean Pixel Intensities (ANOVA Comparison)")
plt.ylabel("Mean Pixel Intensity")
plt.grid(True)
plt.show()

# --- Mean Plot with Error Bars ---
cracked_mean = np.mean(cracked_means)
uncracked_mean = np.mean(uncracked_means)
cracked_std = np.std(cracked_means)
uncracked_std = np.std(uncracked_means)

plt.figure(figsize=(6, 5))
plt.bar(["Cracked", "Uncracked"], [cracked_mean, uncracked_mean],
        yerr=[cracked_std, uncracked_std], capsize=10, color=["salmon", "lightgreen"])
plt.ylabel("Mean Pixel Intensity")
plt.title("Mean Comparison with Error Bars (ANOVA Visual Aid)")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- 9. F1 SCORE ---
y_true = labels
y_pred = np.random.choice([0, 1], size=len(labels))  # Replace with actual model predictions
f1 = f1_score(y_true, y_pred)
print(f"Mock F1 Score (random predictions): {f1:.4f}\n")

# --- F1 Score Bar Graph ---
plt.figure(figsize=(6, 5))
bars = plt.bar(["F1 Score"], [f1], color='skyblue')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.02, f"{yval:.4f}", ha='center', fontsize=12, fontweight='bold')

plt.ylim(0, 1)
plt.ylabel("Score")
plt.title("F1 Score Bar Graph")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# --- 10. Bell Curve (Empirical Rule) ---
all_means = cracked_means + uncracked_means
mu = np.mean(all_means)
sigma = np.std(all_means)

x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = norm.pdf(x, mu, sigma)

plt.figure(figsize=(10, 6))
plt.plot(x, y, color='darkblue', lw=2)
plt.fill_between(x, y, where=(x >= mu - sigma) & (x <= mu + sigma), color='skyblue', alpha=0.5, label='68%')
plt.fill_between(x, y, where=(x >= mu - 2*sigma) & (x <= mu + 2*sigma), color='deepskyblue', alpha=0.4, label='95%')
plt.fill_between(x, y, where=(x >= mu - 3*sigma) & (x <= mu + 3*sigma), color='lightskyblue', alpha=0.3, label='99.7%')

plt.axvline(mu, color='red', linestyle='--', label='Mean')
plt.title("Empirical Rule - Bell Curve of Pixel Intensities")
plt.xlabel("Mean Pixel Intensity")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# --- 11. Chi-Square Test ---

cracked_actual = np.array(y_true) == 1
uncracked_actual = np.array(y_true) == 0

cracked_pred_as_cracked = np.sum((np.array(y_pred) == 1) & cracked_actual)
cracked_pred_as_uncracked = np.sum((np.array(y_pred) == 0) & cracked_actual)
uncracked_pred_as_cracked = np.sum((np.array(y_pred) == 1) & uncracked_actual)
uncracked_pred_as_uncracked = np.sum((np.array(y_pred) == 0) & uncracked_actual)

contingency_table = np.array([
    [cracked_pred_as_cracked, cracked_pred_as_uncracked],
    [uncracked_pred_as_cracked, uncracked_pred_as_uncracked]
])

chi2, p, dof, expected = chi2_contingency(contingency_table)
print("Chi-Square Test:")
print(f"Chi2 Statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:\n", expected)
if p < 0.05:
    print("=> Statistically significant association between prediction and true class.")
else:
    print("=> No significant association between prediction and actual class.")

# --- Chi-Square Bar Chart ---
plt.figure(figsize=(7, 5))
sns.heatmap(contingency_table, annot=True, fmt="d", cmap="Blues", xticklabels=["Pred: Cracked", "Pred: Uncracked"], yticklabels=["True: Cracked", "True: Uncracked"])
plt.title("Chi-Square Contingency Table")
plt.show()
# Out:
# Found 24000 images belonging to 2 classes.
# Found 6000 images belonging to 2 classes.
# ANOVA Test:
# F-statistic: 0.4214
# P-value: 0.5212
# => No significant difference between the two classes.
# Mock F1 Score (random predictions): 0.5405
# Chi-Square Test:
# Chi2 Statistic: 0.0185
# P-value: 0.8918
# Degrees of Freedom: 1
# Expected Frequencies Table:
#  [[10.6875  7.3125]
#  [ 8.3125  5.6875]]
# => No significant association between prediction and actual class.
