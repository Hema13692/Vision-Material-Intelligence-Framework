# %%
from google.colab import drive
import zipfile
import os

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths
zip_path = "/content/drive/My Drive/Walls.zip"  # Change this
extract_path = "/content/unzipped_folder"  # Destination folder in Colab

# Create extraction directory
os.makedirs(extract_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
print("Unzipping done! Extracted files:")
for root, dirs, files in os.walk(extract_path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-5.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-73.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-80.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-207.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-206.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-144.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-49.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-46.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-8.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-183.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-151.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-97.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-92.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-94.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-223.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-202.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-170.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-88.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-191.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-226.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-25.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-95.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-30.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-211.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-144.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-32.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-28.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-239.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-146.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-65.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-83.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-117.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-200.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-176.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-200.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-187.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-181.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-171.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-118.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-203.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-181.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-205.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7089-184.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-184.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-212.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-246.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-154.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-5.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-246.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-164.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-164.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-3.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-123.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-82.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-234.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7113-231.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-149.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-247.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-14.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-19.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-249.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-55.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7087-74.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-47.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-3.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-24.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-95.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-22.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-199.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-26.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-114.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-148.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-12.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-77.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-129.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-154.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-230.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-152.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-175.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-127.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-230.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-243.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-59.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-188.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-217.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-153.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-241.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-7.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-9.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-249.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-113.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-25.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-179.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-71.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-6.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-219.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-202.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-13.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-106.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-62.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-41.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-134.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-34.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-101.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-66.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-249.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-73.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-124.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7078-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-130.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-14.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-237.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-224.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-132.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-132.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-243.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-122.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-140.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-6.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-68.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-12.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-114.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-173.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-83.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-66.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-159.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-24.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-63.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-44.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-247.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-149.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-234.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-7.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-24.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-235.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-19.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-155.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-151.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-238.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-158.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-124.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-126.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-106.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-146.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-244.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-167.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-163.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-76.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-87.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-181.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7087-250.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-163.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-74.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-198.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-215.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-134.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-102.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-231.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-111.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-50.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-119.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-105.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-216.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-198.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-182.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-244.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-237.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-162.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7087-209.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-98.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-63.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-229.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-126.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-20.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7084-203.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-186.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-191.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-23.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-239.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-159.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-44.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-177.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-14.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-60.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-235.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-120.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-217.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-158.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-38.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-71.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-58.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-174.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-56.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-173.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-189.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-195.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-69.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-193.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-224.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-129.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-179.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-250.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-87.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7084-111.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-164.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-127.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-49.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-182.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-133.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-193.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-98.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-182.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-14.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-237.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-182.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-158.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-113.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-104.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-115.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-106.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-39.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-77.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-144.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-68.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-251.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-134.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-146.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-14.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-157.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-127.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-181.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-31.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-201.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-26.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-231.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-225.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-13.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-115.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-194.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-189.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-151.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-249.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-60.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-247.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7087-89.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-3.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-180.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-49.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-251.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-137.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-7.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-59.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-6.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-176.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-19.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-37.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-137.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-77.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-148.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-139.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-204.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7113-37.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-174.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-145.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-210.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-56.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-209.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-211.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-194.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-225.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-39.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-175.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-63.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-94.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-67.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-139.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-211.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-13.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-111.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-252.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-238.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-229.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-77.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-23.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-51.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-71.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-122.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-147.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-210.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-196.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-55.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-95.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-238.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-184.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-93.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-51.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-70.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-202.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-16.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-94.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-78.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-168.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-98.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-149.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-33.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-49.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-240.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-33.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-160.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-39.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-196.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-206.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-97.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-247.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-146.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-21.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-117.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-42.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-102.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-235.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-204.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-239.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-218.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-101.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-141.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-66.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-108.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-245.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-156.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-127.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-74.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-145.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-65.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-144.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-62.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-199.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-122.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7088-187.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-186.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-58.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-160.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-87.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-154.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-15.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-187.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7089-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-217.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-225.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-73.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-106.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7085-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-103.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-179.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-40.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-143.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-183.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-231.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-104.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7090-120.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7071-104.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7079-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7126-212.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-138.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-162.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-209.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-67.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-160.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-210.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-163.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-38.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7084-219.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7091-143.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-92.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7114-119.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-233.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-47.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-151.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-83.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-92.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-23.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-182.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-11.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-11.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-118.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-51.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-54.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-143.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-145.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-143.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-223.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7135-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-226.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-212.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-90.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-76.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-97.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-18.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-148.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-40.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-65.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-42.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-32.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-246.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-223.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7078-132.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-54.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-90.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7138-67.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-196.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-143.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-18.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-105.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7084-140.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7129-65.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-118.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-85.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7078-133.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7105-113.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-150.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7070-167.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-83.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-82.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-246.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-176.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-62.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-92.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-233.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-54.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-223.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-193.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-180.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-207.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7086-159.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7082-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-229.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-191.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-71.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-160.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-233.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-122.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-26.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-122.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-119.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7115-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7139-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-247.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-4.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-186.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-73.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-6.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-28.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7117-32.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-12.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7124-203.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-54.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-229.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-37.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-210.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-123.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7121-224.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-175.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-218.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7111-155.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-83.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-200.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-103.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-34.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7075-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-216.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7078-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7083-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-240.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7108-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7084-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-5.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7098-181.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-199.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7106-85.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-136.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-207.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-4.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-197.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7093-19.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-147.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7125-194.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7110-29.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-90.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7072-199.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7069-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-18.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7089-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-132.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7097-166.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-221.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-199.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7136-235.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7080-59.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-252.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-156.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7119-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7116-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7120-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7118-2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7073-130.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7132-138.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-219.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7076-183.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-9.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7077-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-37.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7140-212.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7122-19.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-75.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7134-196.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7074-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7133-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7099-56.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-36.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7096-237.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7100-123.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7137-22.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7101-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7095-40.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7127-10.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7123-28.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7109-3.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7092-72.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7104-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7107-34.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-33.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-213.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7130-249.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7112-104.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7078-7.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-8.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7131-80.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7128-225.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7102-31.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7081-164.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7094-200.jpg
# /content/unzipped_folder/__MACOSX/Walls/Non-cracked/._7103-119.jpg
# ...
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7112-5.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-42.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7103-112.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-18.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7078-167.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-211.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7102-251.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7074-66.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-174.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7103-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7114-130.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7076-67.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7131-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-165.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7111-215.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7122-203.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-88.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7095-63.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-45.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7126-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7119-69.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7074-78.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-126.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-190.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-1.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-180.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-173.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7118-94.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7120-44.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7077-79.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7131-48.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7136-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7121-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-224.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-66.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-187.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-22.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-10.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7095-173.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7122-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7097-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-150.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-248.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-10.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7107-153_2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-47.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7078-59.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-232.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-44.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7124-243.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-136.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-132.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-70.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7112-150.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-62.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7139-219.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7107-43.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7129-188.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7134-98.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7096-117.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7122-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-41.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7106-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-246.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7071-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-87.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7079-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-135.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7071-60.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-214.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7076-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7104-127.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7118-26.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7131-178.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7104-226.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-11.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7074-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-36.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7119-220.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7072-97.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7115-13.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-62.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7100-241.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-40.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7126-150.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7139-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7096-152.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7120-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7072-148.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-148.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7107-224_2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-153.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7115-67.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-48.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-155.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7078-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-18.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-205.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-39.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-128.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7071-105.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-71.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7107-81_2.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7139-65.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7128-224.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-156.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-137.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7135-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7137-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7104-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-162.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-141.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7097-205.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7130-44.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7099-82.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-146.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7109-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-140.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7107-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-38.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-137.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-179.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7069-158.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-237.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-54.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-95.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-98.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-193.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-149.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7130-27.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-78.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7115-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-222.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-188.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7076-179.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7111-226.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7111-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-82.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-125.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-223.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7072-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7069-64.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7124-218.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-145.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7123-84.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7078-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-99.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7135-11.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-184.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-140.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-212.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-35.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7089-93.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7110-28.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7088-13.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-57.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-51.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7127-6.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7120-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7126-184.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7069-155.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-42.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7124-47.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7076-118.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-5.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7124-60.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-225.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-37.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-120.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7077-191.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7122-207.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7070-97.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-236.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-167.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7127-152.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7120-8.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7127-218.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-113.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7111-86.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7126-228.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7132-171.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-177.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-27.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-74.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7074-85.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7080-29.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-88.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-203.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-53.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-185.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7086-61.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-169.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-180.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7122-131.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-109.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7124-42.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-161.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7085-69.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7134-137.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7079-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7090-55.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-28.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-167.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7079-70.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7094-208.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7119-147.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7075-121.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7112-91.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-250.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7097-96.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7100-157.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7082-172.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7118-142.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7106-81.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-133.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7081-88.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7139-118.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7092-92.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-107.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7087-192.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7084-7.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7083-48.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7077-205.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7137-48.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-108.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7072-85.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7077-151.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7117-60.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7113-190.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7125-242.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7109-194.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7095-227.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7093-38.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7091-129.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7109-138.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7098-100.jpg
# /content/unzipped_folder/__MACOSX/Walls/Cracked/._7082-51.jpg

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, UnidentifiedImageError
from sklearn.metrics import f1_score
from scipy.stats import f_oneway, norm, chi2_contingency
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- 1. Define Paths and Parameters ---
base_dir = "/content/unzipped_folder/Walls"  # Updated path
IMG_SIZE = (128, 128)
BATCH_SIZE = 32

# --- 2. Clean Non-Image Files ---
def is_image_valid(filepath):
    try:
        img = Image.open(filepath)
        img.verify()
        return True
    except (UnidentifiedImageError, IOError):
        return False

def clean_directory(directory):
    removed = 0
    for root, _, files in os.walk(directory):
        for file in files:
            filepath = os.path.join(root, file)
            if not is_image_valid(filepath):
                print(f"Removed: {filepath}")
                os.remove(filepath)
                removed += 1
    print("✅ Cleaning Done" if removed > 0 else "✅ No corrupt files found.")

clean_directory(base_dir)

# --- 3. Load Dataset ---
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training",
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    base_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation",
    shuffle=True
)

print("Class Indices:", train_generator.class_indices)

# --- 4. Fetch a Batch with Both Classes ---
found_cracked = False
for _ in range(10):  # Try 10 times
    X_batch, y_batch = next(train_generator)
    unique_classes = np.unique(y_batch)
    print("Label distribution in batch:", {label: np.sum(y_batch == label) for label in unique_classes})
    if len(unique_classes) > 1:
        found_cracked = True
        break

if not found_cracked:
    raise ValueError("No batch found with both cracked and uncracked images.")

# --- 5. Separate Classes ---
cracked_data = [(img, int(label)) for img, label in zip(X_batch, y_batch) if label == 0]
uncracked_data = [(img, int(label)) for img, label in zip(X_batch, y_batch) if label == 1]

# --- 6. Display Sample Images ---
plt.figure(figsize=(12, 5))
for i in range(min(5, len(cracked_data))):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cracked_data[i][0])
    plt.title("Cracked")
    plt.axis('off')

for i in range(min(5, len(uncracked_data))):
    plt.subplot(2, 5, i + 6)
    plt.imshow(uncracked_data[i][0])
    plt.title("Uncracked")
    plt.axis('off')

plt.tight_layout()
plt.show()

# --- 7. Intensity Analysis ---
cracked_means = [np.mean(img) for img, _ in cracked_data]
uncracked_means = [np.mean(img) for img, _ in uncracked_data]

# --- 8. ANOVA Test ---
f_stat, p_val = f_oneway(cracked_means, uncracked_means)
print(f"\nANOVA Test: F={f_stat:.4f}, P={p_val:.4f}")
print("=> Significant difference" if p_val < 0.05 else "=> No significant difference")

# --- 9. KDE Plot ---
plt.figure(figsize=(8, 6))
sns.kdeplot(cracked_means, label="Cracked", fill=True)
sns.kdeplot(uncracked_means, label="Uncracked", fill=True)
plt.title("Pixel Intensity Distribution")
plt.xlabel("Mean Intensity")
plt.legend()
plt.grid(True)
plt.show()

# --- 10. Box + Bar Plot ---
plt.figure(figsize=(8, 6))
sns.boxplot(data=[cracked_means, uncracked_means], palette=["red", "green"])
plt.xticks([0, 1], ["Cracked", "Uncracked"])
plt.title("Boxplot of Mean Intensities")
plt.grid(True)
plt.show()

# Bar chart
cracked_mean, cracked_std = np.mean(cracked_means), np.std(cracked_means)
uncracked_mean, uncracked_std = np.mean(uncracked_means), np.std(uncracked_means)

plt.figure(figsize=(6, 5))
plt.bar(["Cracked", "Uncracked"], [cracked_mean, uncracked_mean],
        yerr=[cracked_std, uncracked_std], capsize=8, color=["salmon", "lightgreen"])
plt.title("Mean Intensity Comparison")
plt.grid(axis='y')
plt.show()

# --- 11. Mock F1 Score ---
all_data = cracked_data + uncracked_data
np.random.shuffle(all_data)
y_true = [label for _, label in all_data]
y_pred = np.random.choice([0, 1], size=len(y_true))  # Simulated predictions

f1 = f1_score(y_true, y_pred)
print(f"\nMock F1 Score: {f1:.4f}")

# --- F1 Score Plot ---
plt.figure(figsize=(5, 4))
bars = plt.bar(["F1 Score"], [f1], color='skyblue')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02, f"{f1:.4f}", ha='center')
plt.ylim(0, 1)
plt.title("Mock F1 Score")
plt.grid(axis='y')
plt.show()

# --- 12. Bell Curve ---
all_means = cracked_means + uncracked_means
mu, sigma = np.mean(all_means), np.std(all_means)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = norm.pdf(x, mu, sigma)

plt.figure(figsize=(10, 6))
plt.plot(x, y, lw=2)
plt.fill_between(x, y, where=(x >= mu - sigma) & (x <= mu + sigma), color='skyblue', alpha=0.5, label='68%')
plt.fill_between(x, y, where=(x >= mu - 2*sigma) & (x <= mu + 2*sigma), color='deepskyblue', alpha=0.4, label='95%')
plt.fill_between(x, y, where=(x >= mu - 3*sigma) & (x <= mu + 3*sigma), color='lightskyblue', alpha=0.3, label='99.7%')
plt.axvline(mu, color='red', linestyle='--', label='Mean')
plt.title("Empirical Rule - Bell Curve")
plt.xlabel("Pixel Intensity")
plt.legend()
plt.grid(True)
plt.show()

# --- 13. Chi-Square Test ---
true = np.array(y_true)
pred = np.array(y_pred)

table = np.array([
    [np.sum((true == 1) & (pred == 1)), np.sum((true == 1) & (pred == 0))],
    [np.sum((true == 0) & (pred == 1)), np.sum((true == 0) & (pred == 0))]
])

chi2, p, dof, expected = chi2_contingency(table)
print("\nChi-Square Test:")
print(f"Chi2 = {chi2:.4f}, P = {p:.4f}")
print("=> Significant association" if p < 0.05 else "=> No significant association")

# --- Heatmap ---
plt.figure(figsize=(6, 5))
sns.heatmap(table, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Pred: Cracked", "Pred: Uncracked"],
            yticklabels=["True: Cracked", "True: Uncracked"])
plt.title("Chi-Square Contingency Table")
plt.show()
# Out:
# Removed: /content/unzipped_folder/Walls/.DS_Store
# ✅ Cleaning Done
# Found 14511 images belonging to 2 classes.
# Found 3627 images belonging to 2 classes.
# Class Indices: {'Cracked': 0, 'Non-cracked': 1}
# Label distribution in batch: {np.float32(0.0): np.int64(5), np.float32(1.0): np.int64(27)}
# ANOVA Test: F=0.6962, P=0.4107
# => No significant difference
# Mock F1 Score: 0.7111
# Chi-Square Test:
# Chi2 = 0.0941, P = 0.7591
# => No significant association
